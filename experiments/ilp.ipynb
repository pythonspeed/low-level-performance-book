# %%
import os
#os.environ["NUMBA_LOOP_VECTORIZE"] = "0"
#os.environ["NUMBA_OPT"] = "0"
#os.environ["NUMBA_DUMP_ASSEMBLY"] = "1"
from llvmlite import binding as llvm
#llvm.set_option("", "--debug-only=loop-vectorize")

from numba import njit
import numpy as np

# %%
DATA = np.linspace(1, 1_000_000, 1_000_000, dtype=np.uint64)

@njit
def sum(arr):
    total = 0
    for i in range(len(arr)):
        total += arr[i]
    return total

sum(DATA)
# Out:
# 500000500000

# %%
import sys
sys.path.append("../src")
# %load_ext book_magics

# %%
# %%compare_timing
# sum(DATA)
# np.sum(DATA)
# Out:
# |     Code     |Time to run (microseconds)|
# |--------------|-------------------------:|
# |`sum(DATA)`   |                   138.206|
# |`np.sum(DATA)`|                   161.899|

# %%
# %timeit sum(DATA)
# Out:
# 5.02 ms ± 29.9 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
    @njit
    def generate_random_numbers(n):
        result = np.empty((n,), dtype=np.uint64)
        random_number = 1
        for i in range(n):
            random_number = (random_number * 437799614237992725) % (2 ** 61 - 1)
            result[i] = random_number
        return result
    
    generate_random_numbers(3)
# Out:
# array([ 437799614237992725, 1692544495229593526,  262370722887384048],
#       dtype=uint64)

# %%
# %timeit generate_random_numbers(1_000_000)
# Out:
# 11.8 ms ± 122 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
@njit
def generate_random_numbers_2(n):
    result = np.empty((n,), dtype=np.uint64)
    for i in range(n):
        random_number = (i * 437799614237992725) % (2 ** 61 - 1)
        result[i] = random_number
    return result

generate_random_numbers_2(30)
# Out:
# ================================================================================
# -------------------------------OPTIMIZED DUMP nrt-------------------------------
# ; ModuleID = 'nrt'
# source_filename = "<string>"
# target datalayout = "e-m:e-p270:32:32-p271:32:32-p272:64:64-i64:64-f80:128-n8:16:32:64-S128"
# target triple = "x86_64-unknown-linux-gnu"
#
# @.const.pickledata.140635430347264 = internal constant [102 x i8] c"\80\04\95[\00\00\00\00\00\00\00\8C\08builtins\94\8C\0CRuntimeError\94\93\94\8C6numba jitted function aborted due to unresolved symbol\94\85\94N\87\94."
# @.const.pickledata.140635430347264.sha1 = internal constant [20 x i8] c"\97\BE\DC\DF\EC\8E\80\B7\09>P\CE%\EDV\F7r\0E\0C\9C"
# @.const.picklebuf.140635430347264 = internal constant { i8*, i32, i8*, i8*, i32 } { i8* getelementptr inbounds ([102 x i8], [102 x i8]* @.const.pickledata.140635430347264, i32 0, i32 0), i32 102, i8* getelementptr inbounds ([20 x i8], [20 x i8]* @.const.pickledata.140635430347264.sha1, i32 0, i32 0), i8* null, i32 0 }
#
# ; Function Attrs: mustprogress nofree norecurse nounwind willreturn
# define i64 @nrt_atomic_add(i64* nocapture %.1) local_unnamed_addr #0 {
# .3:
#   %.4 = atomicrmw add i64* %.1, i64 1 monotonic, align 8
#   %.5 = add i64 %.4, 1
#   ret i64 %.5
# }
#
# ; Function Attrs: mustprogress nofree norecurse nounwind willreturn
# define i64 @nrt_atomic_sub(i64* nocapture %.1) local_unnamed_addr #0 {
# .3:
#   %.4 = atomicrmw sub i64* %.1, i64 1 monotonic, align 8
#   %.5 = add i64 %.4, -1
#   ret i64 %.5
# }
#
# ; Function Attrs: mustprogress nofree norecurse nounwind willreturn
# define i32 @nrt_atomic_cas(i64* nocapture %.1, i64 %.2, i64 %.3, i64* nocapture writeonly %.4) local_unnamed_addr #0 {
# .6:
#   %.7 = cmpxchg i64* %.1, i64 %.2, i64 %.3 monotonic monotonic, align 8
#   %.8 = extractvalue { i64, i1 } %.7, 0
#   %.9 = extractvalue { i64, i1 } %.7, 1
#   store i64 %.8, i64* %.4, align 8
#   %.11 = zext i1 %.9 to i32
#   ret i32 %.11
# }
#
# ; Function Attrs: mustprogress nofree norecurse nosync nounwind readonly willreturn
# define i8* @NRT_MemInfo_data_fast(i8* nocapture readonly %.1) local_unnamed_addr #1 {
# .3:
#   %.5 = getelementptr i8, i8* %.1, i64 24
#   %0 = bitcast i8* %.5 to i8**
#   %.6 = load i8*, i8** %0, align 8
#   ret i8* %.6
# }
#
# ; Function Attrs: mustprogress nofree noinline norecurse nounwind willreturn
# define void @NRT_incref(i8* %.1) local_unnamed_addr #2 {
# .3:
#   %.4 = icmp eq i8* %.1, null
#   br i1 %.4, label %common.ret, label %.3.endif, !prof !0
#
# common.ret:                                       ; preds = %.3, %.3.endif
#   ret void
#
# .3.endif:                                         ; preds = %.3
#   %.7 = bitcast i8* %.1 to i64*
#   %.4.i = atomicrmw add i64* %.7, i64 1 monotonic, align 8
#   br label %common.ret
# }
#
# ; Function Attrs: noinline
# define void @NRT_decref(i8* %.1) local_unnamed_addr #3 {
# .3:
#   %.4 = icmp eq i8* %.1, null
#   br i1 %.4, label %common.ret, label %.3.endif, !prof !0
#
# common.ret:                                       ; preds = %.3.endif, %.3
#   ret void
#
# .3.endif:                                         ; preds = %.3
#   fence release
#   %.8 = bitcast i8* %.1 to i64*
#   %.4.i = atomicrmw sub i64* %.8, i64 1 monotonic, align 8
#   %.10 = icmp eq i64 %.4.i, 1
#   br i1 %.10, label %.3.endif.if, label %common.ret, !prof !0
#
# .3.endif.if:                                      ; preds = %.3.endif
#   fence acquire
#   tail call void @NRT_MemInfo_call_dtor(i8* nonnull %.1)
#   ret void
# }
#
# declare void @NRT_MemInfo_call_dtor(i8*) local_unnamed_addr
#
# ; Function Attrs: mustprogress nofree norecurse nosync nounwind willreturn writeonly
# define i32 @nrt_unresolved_abort(i8** nocapture readnone %.1, { i8*, i32, i8*, i8*, i32 }** nocapture writeonly %.2) local_unnamed_addr #4 {
# .4:
#   store { i8*, i32, i8*, i8*, i32 }* @.const.picklebuf.140635430347264, { i8*, i32, i8*, i8*, i32 }** %.2, align 8, !numba_exception_output !1
#   ret i32 1
# }
#
# attributes #0 = { mustprogress nofree norecurse nounwind willreturn }
# attributes #1 = { mustprogress nofree norecurse nosync nounwind readonly willreturn }
# attributes #2 = { mustprogress nofree noinline norecurse nounwind willreturn }
# attributes #3 = { noinline }
# attributes #4 = { mustprogress nofree norecurse nosync nounwind willreturn writeonly }
#
# !0 = !{!"branch_weights", i32 1, i32 99}
# !1 = !{i1 true}
#
# ================================================================================
# ================================================================================
# ----------------OPTIMIZED DUMP _ol_array_allocate.<locals>.impl-----------------
# ; ModuleID = '_ol_array_allocate.<locals>.impl'
# source_filename = "<string>"
# target datalayout = "e-m:e-p270:32:32-p271:32:32-p272:64:64-i64:64-f80:128-n8:16:32:64-S128"
# target triple = "x86_64-unknown-linux-gnu"
#
# @_ZN08NumbaEnv5numba2np8arrayobj18_ol_array_allocate12_3clocals_3e4implB2v4B42c8tJTIcFKzyF2ILShI4CrgQElcaMVJhEEUSJJgA_3dEN29typeref_5b_3cclass_20_27numba4core5types8npytypes14Array_27_3e_5dExj = common local_unnamed_addr global i8* null
# @.const.pickledata.140635421704384 = internal constant [86 x i8] c"\80\04\95K\00\00\00\00\00\00\00\8C\08builtins\94\8C\0BMemoryError\94\93\94\8C'Allocation failed (probably too large).\94\85\94N\87\94."
# @.const.pickledata.140635421704384.sha1 = internal constant [20 x i8] c"\BA(\9D\81\F0\\p \F3G|\15sH\04\DFe\AB\E2\09"
# @.const.picklebuf.140635421704384 = internal constant { i8*, i32, i8*, i8*, i32 } { i8* getelementptr inbounds ([86 x i8], [86 x i8]* @.const.pickledata.140635421704384, i32 0, i32 0), i32 86, i8* getelementptr inbounds ([20 x i8], [20 x i8]* @.const.pickledata.140635421704384.sha1, i32 0, i32 0), i8* null, i32 0 }
# @PyExc_RuntimeError = external global i8
# @".const.Error creating Python tuple from runtime exception arguments" = internal constant [61 x i8] c"Error creating Python tuple from runtime exception arguments\00"
# @PyExc_SystemError = external global i8
# @".const.unknown error when calling native function" = internal constant [43 x i8] c"unknown error when calling native function\00"
# @".const.<numba.core.cpu.CPUContext object at 0x7fe83c5235e0>" = internal constant [53 x i8] c"<numba.core.cpu.CPUContext object at 0x7fe83c5235e0>\00"
#
# define i32 @_ZN5numba2np8arrayobj18_ol_array_allocate12_3clocals_3e4implB2v4B42c8tJTIcFKzyF2ILShI4CrgQElcaMVJhEEUSJJgA_3dEN29typeref_5b_3cclass_20_27numba4core5types8npytypes14Array_27_3e_5dExj(i8** noalias nocapture writeonly %retptr, { i8*, i32, i8*, i8*, i32 }** noalias nocapture writeonly %excinfo, i8* nocapture readnone %arg.cls, i64 %arg.allocsize, i32 %arg.align) local_unnamed_addr {
# entry:
#   %.7 = tail call i8* @NRT_MemInfo_alloc_aligned(i64 %arg.allocsize, i32 %arg.align)
#   %.8 = icmp eq i8* %.7, null
#   br i1 %.8, label %B0.if, label %B0.endif, !prof !0
#
# common.ret:                                       ; preds = %B0.endif, %B0.if
#   %common.ret.op = phi i32 [ 1, %B0.if ], [ 0, %B0.endif ]
#   ret i32 %common.ret.op
#
# B0.if:                                            ; preds = %entry
#   store { i8*, i32, i8*, i8*, i32 }* @.const.picklebuf.140635421704384, { i8*, i32, i8*, i8*, i32 }** %excinfo, align 8, !numba_exception_output !1
#   br label %common.ret
#
# B0.endif:                                         ; preds = %entry
#   store i8* %.7, i8** %retptr, align 8
#   br label %common.ret
# }
#
# declare noalias i8* @NRT_MemInfo_alloc_aligned(i64, i32) local_unnamed_addr
#
# define i8* @cfunc._ZN5numba2np8arrayobj18_ol_array_allocate12_3clocals_3e4implB2v4B42c8tJTIcFKzyF2ILShI4CrgQElcaMVJhEEUSJJgA_3dEN29typeref_5b_3cclass_20_27numba4core5types8npytypes14Array_27_3e_5dExj(i8* nocapture readnone %.1, i64 %.2, i32 %.3) local_unnamed_addr {
# entry:
#   %.5 = alloca i8*, align 8
#   store i8* null, i8** %.5, align 8
#   %excinfo = alloca { i8*, i32, i8*, i8*, i32 }*, align 8
#   store { i8*, i32, i8*, i8*, i32 }* null, { i8*, i32, i8*, i8*, i32 }** %excinfo, align 8
#   %.9 = call i32 @_ZN5numba2np8arrayobj18_ol_array_allocate12_3clocals_3e4implB2v4B42c8tJTIcFKzyF2ILShI4CrgQElcaMVJhEEUSJJgA_3dEN29typeref_5b_3cclass_20_27numba4core5types8npytypes14Array_27_3e_5dExj(i8** nonnull %.5, { i8*, i32, i8*, i8*, i32 }** nonnull %excinfo, i8* undef, i64 %.2, i32 %.3) #0
#   %.10 = load { i8*, i32, i8*, i8*, i32 }*, { i8*, i32, i8*, i8*, i32 }** %excinfo, align 8
#   %.11.not = icmp eq i32 %.9, 0
#   %.17 = icmp sgt i32 %.9, 0
#   %.18 = select i1 %.17, { i8*, i32, i8*, i8*, i32 }* %.10, { i8*, i32, i8*, i8*, i32 }* undef
#   %.19 = load i8*, i8** %.5, align 8
#   %.21 = alloca i32, align 4
#   store i32 0, i32* %.21, align 4
#   br i1 %.11.not, label %common.ret, label %entry.if, !prof !2
#
# entry.if:                                         ; preds = %entry
#   %0 = icmp sgt i32 %.9, 0
#   call void @numba_gil_ensure(i32* nonnull %.21)
#   br i1 %0, label %entry.if.if, label %entry.if.endif.endif.endif
#
# common.ret:                                       ; preds = %entry, %.24, %entry.if.if.if.if
#   %common.ret.op = phi i8* [ null, %entry.if.if.if.if ], [ %.19, %.24 ], [ %.19, %entry ]
#   ret i8* %common.ret.op
#
# .24:                                              ; preds = %entry.if.if.endif, %entry.if.if.endif.if, %entry.if.endif.endif.endif
#   %.72 = call i8* @PyUnicode_FromString(i8* getelementptr inbounds ([53 x i8], [53 x i8]* @".const.<numba.core.cpu.CPUContext object at 0x7fe83c5235e0>", i64 0, i64 0))
#   call void @PyErr_WriteUnraisable(i8* %.72)
#   call void @Py_DecRef(i8* %.72)
#   call void @numba_gil_release(i32* nonnull %.21)
#   br label %common.ret
#
# entry.if.if:                                      ; preds = %entry.if
#   call void @PyErr_Clear()
#   %.27 = load { i8*, i32, i8*, i8*, i32 }, { i8*, i32, i8*, i8*, i32 }* %.18, align 8
#   %.28 = extractvalue { i8*, i32, i8*, i8*, i32 } %.27, 4
#   %.29 = icmp sgt i32 %.28, 0
#   %.32 = extractvalue { i8*, i32, i8*, i8*, i32 } %.27, 0
#   %.34 = extractvalue { i8*, i32, i8*, i8*, i32 } %.27, 1
#   br i1 %.29, label %entry.if.if.if, label %entry.if.if.else
#
# entry.if.if.if:                                   ; preds = %entry.if.if
#   %.35 = sext i32 %.34 to i64
#   %.36 = call i8* @PyBytes_FromStringAndSize(i8* %.32, i64 %.35)
#   %.37 = load { i8*, i32, i8*, i8*, i32 }, { i8*, i32, i8*, i8*, i32 }* %.18, align 8
#   %.38 = extractvalue { i8*, i32, i8*, i8*, i32 } %.37, 2
#   %.40 = extractvalue { i8*, i32, i8*, i8*, i32 } %.37, 3
#   %.41 = bitcast i8* %.40 to i8* (i8*)*
#   %.42 = call i8* %.41(i8* %.38)
#   %.43 = icmp eq i8* %.42, null
#   br i1 %.43, label %entry.if.if.if.if, label %entry.if.if.if.endif, !prof !0
#
# entry.if.if.else:                                 ; preds = %entry.if.if
#   %.56 = extractvalue { i8*, i32, i8*, i8*, i32 } %.27, 2
#   %.57 = call i8* @numba_unpickle(i8* %.32, i32 %.34, i8* %.56)
#   br label %entry.if.if.endif
#
# entry.if.if.endif:                                ; preds = %entry.if.if.if.endif, %entry.if.if.else
#   %.59 = phi i8* [ %.47, %entry.if.if.if.endif ], [ %.57, %entry.if.if.else ]
#   %.60.not = icmp eq i8* %.59, null
#   br i1 %.60.not, label %.24, label %entry.if.if.endif.if, !prof !0
#
# entry.if.if.if.if:                                ; preds = %entry.if.if.if
#   call void @PyErr_SetString(i8* nonnull @PyExc_RuntimeError, i8* getelementptr inbounds ([61 x i8], [61 x i8]* @".const.Error creating Python tuple from runtime exception arguments", i64 0, i64 0))
#   br label %common.ret
#
# entry.if.if.if.endif:                             ; preds = %entry.if.if.if
#   %.47 = call i8* @numba_runtime_build_excinfo_struct(i8* %.36, i8* nonnull %.42)
#   %.48 = bitcast { i8*, i32, i8*, i8*, i32 }* %.18 to i8*
#   call void @NRT_Free(i8* nonnull %.48)
#   br label %entry.if.if.endif
#
# entry.if.if.endif.if:                             ; preds = %entry.if.if.endif
#   call void @numba_do_raise(i8* nonnull %.59)
#   br label %.24
#
# entry.if.endif.endif.endif:                       ; preds = %entry.if
#   call void @PyErr_SetString(i8* nonnull @PyExc_SystemError, i8* getelementptr inbounds ([43 x i8], [43 x i8]* @".const.unknown error when calling native function", i64 0, i64 0))
#   br label %.24
# }
#
# declare void @numba_gil_ensure(i32*) local_unnamed_addr
#
# declare i8* @PyUnicode_FromString(i8*) local_unnamed_addr
#
# declare void @PyErr_WriteUnraisable(i8*) local_unnamed_addr
#
# declare void @Py_DecRef(i8*) local_unnamed_addr
#
# declare void @numba_gil_release(i32*) local_unnamed_addr
#
# declare void @PyErr_Clear() local_unnamed_addr
#
# declare i8* @PyBytes_FromStringAndSize(i8*, i64) local_unnamed_addr
#
# declare i8* @numba_unpickle(i8*, i32, i8*) local_unnamed_addr
#
# declare void @PyErr_SetString(i8*, i8*) local_unnamed_addr
#
# declare i8* @numba_runtime_build_excinfo_struct(i8*, i8*) local_unnamed_addr
#
# declare void @NRT_Free(i8*) local_unnamed_addr
#
# declare void @numba_do_raise(i8*) local_unnamed_addr
#
# attributes #0 = { noinline }
#
# !0 = !{!"branch_weights", i32 1, i32 99}
# !1 = !{i1 true}
# !2 = !{!"branch_weights", i32 99, i32 1}
#
# ================================================================================
# ================================================================================
# -------------------------OPTIMIZED DUMP _call_allocator-------------------------
# ; ModuleID = '_call_allocator'
# source_filename = "<string>"
# target datalayout = "e-m:e-p270:32:32-p271:32:32-p272:64:64-i64:64-f80:128-n8:16:32:64-S128"
# target triple = "x86_64-unknown-linux-gnu"
#
# @_ZN08NumbaEnv5numba2np8arrayobj15_call_allocatorB2v3B42c8tJTC_2fWQI8IW1CiAAYKPM6RBFDjESZRVAJmaQIAEN29typeref_5b_3cclass_20_27numba4core5types8npytypes14Array_27_3e_5dExj = common local_unnamed_addr global i8* null
# @_ZN08NumbaEnv5numba2np8arrayobj18_ol_array_allocate12_3clocals_3e4implB2v4B42c8tJTIcFKzyF2ILShI4CrgQElcaMVJhEEUSJJgA_3dEN29typeref_5b_3cclass_20_27numba4core5types8npytypes14Array_27_3e_5dExj = common local_unnamed_addr global i8* null
# @.const.pickledata.140635421704384 = internal constant [86 x i8] c"\80\04\95K\00\00\00\00\00\00\00\8C\08builtins\94\8C\0BMemoryError\94\93\94\8C'Allocation failed (probably too large).\94\85\94N\87\94."
# @.const.pickledata.140635421704384.sha1 = internal constant [20 x i8] c"\BA(\9D\81\F0\\p \F3G|\15sH\04\DFe\AB\E2\09"
# @.const.picklebuf.140635421704384 = internal constant { i8*, i32, i8*, i8*, i32 } { i8* getelementptr inbounds ([86 x i8], [86 x i8]* @.const.pickledata.140635421704384, i32 0, i32 0), i32 86, i8* getelementptr inbounds ([20 x i8], [20 x i8]* @.const.pickledata.140635421704384.sha1, i32 0, i32 0), i8* null, i32 0 }
#
# define i32 @_ZN5numba2np8arrayobj15_call_allocatorB2v3B42c8tJTC_2fWQI8IW1CiAAYKPM6RBFDjESZRVAJmaQIAEN29typeref_5b_3cclass_20_27numba4core5types8npytypes14Array_27_3e_5dExj(i8** noalias nocapture writeonly %retptr, { i8*, i32, i8*, i8*, i32 }** noalias nocapture writeonly %excinfo, i8* nocapture readnone %arg.arrtype, i64 %arg.size, i32 %arg.align) local_unnamed_addr {
# entry:
#   %.7.i = tail call i8* @NRT_MemInfo_alloc_aligned(i64 %arg.size, i32 %arg.align), !noalias !0
#   %.8.i = icmp eq i8* %.7.i, null
#   br i1 %.8.i, label %B0.if, label %B0.endif, !prof !4
#
# B0.if:                                            ; preds = %entry
#   store { i8*, i32, i8*, i8*, i32 }* @.const.picklebuf.140635421704384, { i8*, i32, i8*, i8*, i32 }** %excinfo, align 8
#   br label %common.ret
#
# common.ret:                                       ; preds = %B0.if, %B0.endif
#   %common.ret.op = phi i32 [ 0, %B0.endif ], [ 1, %B0.if ]
#   ret i32 %common.ret.op
#
# B0.endif:                                         ; preds = %entry
#   store i8* %.7.i, i8** %retptr, align 8
#   br label %common.ret
# }
#
# declare noalias i8* @NRT_MemInfo_alloc_aligned(i64, i32) local_unnamed_addr
#
# !0 = !{!1, !3}
# !1 = distinct !{!1, !2, !"_ZN5numba2np8arrayobj18_ol_array_allocate12_3clocals_3e4implB2v4B42c8tJTIcFKzyF2ILShI4CrgQElcaMVJhEEUSJJgA_3dEN29typeref_5b_3cclass_20_27numba4core5types8npytypes14Array_27_3e_5dExj: %retptr"}
# !2 = distinct !{!2, !"_ZN5numba2np8arrayobj18_ol_array_allocate12_3clocals_3e4implB2v4B42c8tJTIcFKzyF2ILShI4CrgQElcaMVJhEEUSJJgA_3dEN29typeref_5b_3cclass_20_27numba4core5types8npytypes14Array_27_3e_5dExj"}
# !3 = distinct !{!3, !2, !"_ZN5numba2np8arrayobj18_ol_array_allocate12_3clocals_3e4implB2v4B42c8tJTIcFKzyF2ILShI4CrgQElcaMVJhEEUSJJgA_3dEN29typeref_5b_3cclass_20_27numba4core5types8npytypes14Array_27_3e_5dExj: %excinfo"}
# !4 = !{!"branch_weights", i32 1, i32 99}
#
# ================================================================================
# ================================================================================
# --------------------OPTIMIZED DUMP ol_np_empty.<locals>.impl--------------------
# ; ModuleID = 'ol_np_empty.<locals>.impl'
# source_filename = "<string>"
# target datalayout = "e-m:e-p270:32:32-p271:32:32-p272:64:64-i64:64-f80:128-n8:16:32:64-S128"
# target triple = "x86_64-unknown-linux-gnu"
#
# @_ZN08NumbaEnv5numba2np8arrayobj11ol_np_empty12_3clocals_3e4implB2v2B42c8tJTIcFKzyF2ILShI4CrgQElcaMVJhEEUSJJgA_3dE8UniTupleIxLi1EE17class_28uint64_29 = common local_unnamed_addr global i8* null
# @.const.pickledata.140635422855360 = internal constant [77 x i8] c"\80\04\95B\00\00\00\00\00\00\00\8C\08builtins\94\8C\0AValueError\94\93\94\8C\1Fnegative dimensions not allowed\94\85\94N\87\94."
# @.const.pickledata.140635422855360.sha1 = internal constant [20 x i8] c"3\1B\85c\BD\B9\DA\C8\1B8B\22s\05,Ho\C1pk"
# @.const.picklebuf.140635422855360 = internal constant { i8*, i32, i8*, i8*, i32 } { i8* getelementptr inbounds ([77 x i8], [77 x i8]* @.const.pickledata.140635422855360, i32 0, i32 0), i32 77, i8* getelementptr inbounds ([20 x i8], [20 x i8]* @.const.pickledata.140635422855360.sha1, i32 0, i32 0), i8* null, i32 0 }
# @.const.pickledata.140635420988416 = internal constant [137 x i8] c"\80\04\95~\00\00\00\00\00\00\00\8C\08builtins\94\8C\0AValueError\94\93\94\8C[array is too big; `arr.size * arr.dtype.itemsize` is larger than the maximum possible size.\94\85\94N\87\94."
# @.const.pickledata.140635420988416.sha1 = internal constant [20 x i8] c"X\E1N\CC\B5\07\B1\E0 i\81t\02#\E6\85\CB\8C<W"
# @.const.picklebuf.140635420988416 = internal constant { i8*, i32, i8*, i8*, i32 } { i8* getelementptr inbounds ([137 x i8], [137 x i8]* @.const.pickledata.140635420988416, i32 0, i32 0), i32 137, i8* getelementptr inbounds ([20 x i8], [20 x i8]* @.const.pickledata.140635420988416.sha1, i32 0, i32 0), i8* null, i32 0 }
# @PyExc_RuntimeError = external global i8
# @".const.Error creating Python tuple from runtime exception arguments" = internal constant [61 x i8] c"Error creating Python tuple from runtime exception arguments\00"
# @PyExc_SystemError = external global i8
# @".const.unknown error when calling native function" = internal constant [43 x i8] c"unknown error when calling native function\00"
# @".const.<numba.core.cpu.CPUContext object at 0x7fe83c6b1390>" = internal constant [53 x i8] c"<numba.core.cpu.CPUContext object at 0x7fe83c6b1390>\00"
# @_ZN08NumbaEnv5numba2np8arrayobj15_call_allocatorB2v3B42c8tJTC_2fWQI8IW1CiAAYKPM6RBFDjESZRVAJmaQIAEN29typeref_5b_3cclass_20_27numba4core5types8npytypes14Array_27_3e_5dExj = common local_unnamed_addr global i8* null
# @_ZN08NumbaEnv5numba2np8arrayobj18_ol_array_allocate12_3clocals_3e4implB2v4B42c8tJTIcFKzyF2ILShI4CrgQElcaMVJhEEUSJJgA_3dEN29typeref_5b_3cclass_20_27numba4core5types8npytypes14Array_27_3e_5dExj = common local_unnamed_addr global i8* null
# @.const.pickledata.140635421704384 = internal constant [86 x i8] c"\80\04\95K\00\00\00\00\00\00\00\8C\08builtins\94\8C\0BMemoryError\94\93\94\8C'Allocation failed (probably too large).\94\85\94N\87\94."
# @.const.pickledata.140635421704384.sha1 = internal constant [20 x i8] c"\BA(\9D\81\F0\\p \F3G|\15sH\04\DFe\AB\E2\09"
# @.const.picklebuf.140635421704384 = internal constant { i8*, i32, i8*, i8*, i32 } { i8* getelementptr inbounds ([86 x i8], [86 x i8]* @.const.pickledata.140635421704384, i32 0, i32 0), i32 86, i8* getelementptr inbounds ([20 x i8], [20 x i8]* @.const.pickledata.140635421704384.sha1, i32 0, i32 0), i8* null, i32 0 }
#
# define i32 @_ZN5numba2np8arrayobj11ol_np_empty12_3clocals_3e4implB2v2B42c8tJTIcFKzyF2ILShI4CrgQElcaMVJhEEUSJJgA_3dE8UniTupleIxLi1EE17class_28uint64_29({ i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }* noalias nocapture writeonly %retptr, { i8*, i32, i8*, i8*, i32 }** noalias nocapture writeonly %excinfo, i64 %arg.shape.0, i8* nocapture readnone %arg.dtype) local_unnamed_addr {
# B0.endif:
#   %.18 = icmp slt i64 %arg.shape.0, 0
#   br i1 %.18, label %B0.endif.if, label %B0.endif.endif, !prof !0
#
# common.ret:                                       ; preds = %B0.endif.endif.endif.if, %B0.endif.endif.endif.endif, %B0.endif.endif.if, %B0.endif.if
#   %common.ret.op = phi i32 [ 1, %B0.endif.if ], [ 1, %B0.endif.endif.if ], [ 0, %B0.endif.endif.endif.endif ], [ 1, %B0.endif.endif.endif.if ]
#   ret i32 %common.ret.op
#
# B0.endif.if:                                      ; preds = %B0.endif
#   store { i8*, i32, i8*, i8*, i32 }* @.const.picklebuf.140635422855360, { i8*, i32, i8*, i8*, i32 }** %excinfo, align 8, !numba_exception_output !1
#   br label %common.ret
#
# B0.endif.endif:                                   ; preds = %B0.endif
#   %.32 = tail call { i64, i1 } @llvm.smul.with.overflow.i64(i64 %arg.shape.0, i64 8)
#   %.34 = extractvalue { i64, i1 } %.32, 1
#   br i1 %.34, label %B0.endif.endif.if, label %B0.endif.endif.endif, !prof !0
#
# B0.endif.endif.if:                                ; preds = %B0.endif.endif
#   store { i8*, i32, i8*, i8*, i32 }* @.const.picklebuf.140635420988416, { i8*, i32, i8*, i8*, i32 }** %excinfo, align 8, !numba_exception_output !1
#   br label %common.ret
#
# B0.endif.endif.endif:                             ; preds = %B0.endif.endif
#   %.33 = extractvalue { i64, i1 } %.32, 0
#   %.7.i.i = tail call i8* @NRT_MemInfo_alloc_aligned(i64 %.33, i32 32), !noalias !2
#   %.8.i.i = icmp eq i8* %.7.i.i, null
#   br i1 %.8.i.i, label %B0.endif.endif.endif.if, label %B0.endif.endif.endif.endif, !prof !0
#
# B0.endif.endif.endif.if:                          ; preds = %B0.endif.endif.endif
#   store { i8*, i32, i8*, i8*, i32 }* @.const.picklebuf.140635421704384, { i8*, i32, i8*, i8*, i32 }** %excinfo, align 8
#   br label %common.ret
#
# B0.endif.endif.endif.endif:                       ; preds = %B0.endif.endif.endif
#   %.5.i = getelementptr i8, i8* %.7.i.i, i64 24
#   %0 = bitcast i8* %.5.i to i64**
#   %.6.i1 = load i64*, i64** %0, align 8
#   %retptr.repack19 = bitcast { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }* %retptr to i8**
#   store i8* %.7.i.i, i8** %retptr.repack19, align 8
#   %retptr.repack2 = getelementptr inbounds { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }, { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }* %retptr, i64 0, i32 1
#   store i8* null, i8** %retptr.repack2, align 8
#   %retptr.repack4 = getelementptr inbounds { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }, { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }* %retptr, i64 0, i32 2
#   store i64 %arg.shape.0, i64* %retptr.repack4, align 8
#   %retptr.repack6 = getelementptr inbounds { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }, { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }* %retptr, i64 0, i32 3
#   store i64 8, i64* %retptr.repack6, align 8
#   %retptr.repack8 = getelementptr inbounds { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }, { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }* %retptr, i64 0, i32 4
#   store i64* %.6.i1, i64** %retptr.repack8, align 8
#   %1 = getelementptr inbounds { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }, { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }* %retptr, i64 0, i32 5, i64 0
#   store i64 %arg.shape.0, i64* %1, align 8
#   %2 = getelementptr inbounds { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }, { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }* %retptr, i64 0, i32 6, i64 0
#   store i64 8, i64* %2, align 8
#   br label %common.ret
# }
#
# ; Function Attrs: mustprogress nofree nosync nounwind readnone speculatable willreturn
# declare { i64, i1 } @llvm.smul.with.overflow.i64(i64, i64) #0
#
# define { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] } @cfunc._ZN5numba2np8arrayobj11ol_np_empty12_3clocals_3e4implB2v2B42c8tJTIcFKzyF2ILShI4CrgQElcaMVJhEEUSJJgA_3dE8UniTupleIxLi1EE17class_28uint64_29([1 x i64] %.1, i8* nocapture readnone %.2) local_unnamed_addr {
# entry:
#   %.4 = alloca { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }, align 8
#   %.fca.0.gep1 = bitcast { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }* %.4 to i8**
#   %.fca.1.gep = getelementptr inbounds { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }, { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }* %.4, i64 0, i32 1
#   %.fca.2.gep = getelementptr inbounds { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }, { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }* %.4, i64 0, i32 2
#   %.fca.3.gep = getelementptr inbounds { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }, { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }* %.4, i64 0, i32 3
#   %.fca.4.gep = getelementptr inbounds { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }, { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }* %.4, i64 0, i32 4
#   %.fca.5.0.gep = getelementptr inbounds { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }, { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }* %.4, i64 0, i32 5, i64 0
#   %.fca.6.0.gep = getelementptr inbounds { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }, { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }* %.4, i64 0, i32 6, i64 0
#   %excinfo = alloca { i8*, i32, i8*, i8*, i32 }*, align 8
#   %0 = bitcast { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }* %.4 to i8*
#   call void @llvm.memset.p0i8.i64(i8* noundef nonnull align 8 dereferenceable(56) %0, i8 0, i64 56, i1 false)
#   store { i8*, i32, i8*, i8*, i32 }* null, { i8*, i32, i8*, i8*, i32 }** %excinfo, align 8
#   %.8 = extractvalue [1 x i64] %.1, 0
#   %.9 = call i32 @_ZN5numba2np8arrayobj11ol_np_empty12_3clocals_3e4implB2v2B42c8tJTIcFKzyF2ILShI4CrgQElcaMVJhEEUSJJgA_3dE8UniTupleIxLi1EE17class_28uint64_29({ i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }* nonnull %.4, { i8*, i32, i8*, i8*, i32 }** nonnull %excinfo, i64 %.8, i8* undef) #2
#   %.10 = load { i8*, i32, i8*, i8*, i32 }*, { i8*, i32, i8*, i8*, i32 }** %excinfo, align 8
#   %.11.not = icmp eq i32 %.9, 0
#   %.17 = icmp sgt i32 %.9, 0
#   %.18 = select i1 %.17, { i8*, i32, i8*, i8*, i32 }* %.10, { i8*, i32, i8*, i8*, i32 }* undef
#   %.19.fca.0.load = load i8*, i8** %.fca.0.gep1, align 8
#   %.19.fca.1.load = load i8*, i8** %.fca.1.gep, align 8
#   %.19.fca.2.load = load i64, i64* %.fca.2.gep, align 8
#   %.19.fca.3.load = load i64, i64* %.fca.3.gep, align 8
#   %.19.fca.4.load = load i64*, i64** %.fca.4.gep, align 8
#   %.19.fca.5.0.load = load i64, i64* %.fca.5.0.gep, align 8
#   %.19.fca.6.0.load = load i64, i64* %.fca.6.0.gep, align 8
#   %.25 = insertvalue [1 x i64] poison, i64 %.19.fca.5.0.load, 0
#   %.26 = insertvalue [1 x i64] poison, i64 %.19.fca.6.0.load, 0
#   %inserted.meminfo = insertvalue { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] } undef, i8* %.19.fca.0.load, 0
#   %inserted.parent = insertvalue { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] } %inserted.meminfo, i8* %.19.fca.1.load, 1
#   %inserted.nitems = insertvalue { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] } %inserted.parent, i64 %.19.fca.2.load, 2
#   %inserted.itemsize = insertvalue { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] } %inserted.nitems, i64 %.19.fca.3.load, 3
#   %inserted.data = insertvalue { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] } %inserted.itemsize, i64* %.19.fca.4.load, 4
#   %inserted.shape = insertvalue { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] } %inserted.data, [1 x i64] %.25, 5
#   %inserted.strides = insertvalue { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] } %inserted.shape, [1 x i64] %.26, 6
#   %.32 = alloca i32, align 4
#   store i32 0, i32* %.32, align 4
#   br i1 %.11.not, label %common.ret, label %entry.if, !prof !9
#
# entry.if:                                         ; preds = %entry
#   %1 = icmp sgt i32 %.9, 0
#   call void @numba_gil_ensure(i32* nonnull %.32)
#   br i1 %1, label %entry.if.if, label %entry.if.endif.endif.endif
#
# common.ret:                                       ; preds = %entry, %.35, %entry.if.if.if.if
#   %common.ret.op = phi { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] } [ zeroinitializer, %entry.if.if.if.if ], [ %inserted.strides, %.35 ], [ %inserted.strides, %entry ]
#   ret { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] } %common.ret.op
#
# .35:                                              ; preds = %entry.if.if.endif, %entry.if.if.endif.if, %entry.if.endif.endif.endif
#   %.83 = call i8* @PyUnicode_FromString(i8* getelementptr inbounds ([53 x i8], [53 x i8]* @".const.<numba.core.cpu.CPUContext object at 0x7fe83c6b1390>", i64 0, i64 0))
#   call void @PyErr_WriteUnraisable(i8* %.83)
#   call void @Py_DecRef(i8* %.83)
#   call void @numba_gil_release(i32* nonnull %.32)
#   br label %common.ret
#
# entry.if.if:                                      ; preds = %entry.if
#   call void @PyErr_Clear()
#   %.38 = load { i8*, i32, i8*, i8*, i32 }, { i8*, i32, i8*, i8*, i32 }* %.18, align 8
#   %.39 = extractvalue { i8*, i32, i8*, i8*, i32 } %.38, 4
#   %.40 = icmp sgt i32 %.39, 0
#   %.43 = extractvalue { i8*, i32, i8*, i8*, i32 } %.38, 0
#   %.45 = extractvalue { i8*, i32, i8*, i8*, i32 } %.38, 1
#   br i1 %.40, label %entry.if.if.if, label %entry.if.if.else
#
# entry.if.if.if:                                   ; preds = %entry.if.if
#   %.46 = sext i32 %.45 to i64
#   %.47 = call i8* @PyBytes_FromStringAndSize(i8* %.43, i64 %.46)
#   %.48 = load { i8*, i32, i8*, i8*, i32 }, { i8*, i32, i8*, i8*, i32 }* %.18, align 8
#   %.49 = extractvalue { i8*, i32, i8*, i8*, i32 } %.48, 2
#   %.51 = extractvalue { i8*, i32, i8*, i8*, i32 } %.48, 3
#   %.52 = bitcast i8* %.51 to i8* (i8*)*
#   %.53 = call i8* %.52(i8* %.49)
#   %.54 = icmp eq i8* %.53, null
#   br i1 %.54, label %entry.if.if.if.if, label %entry.if.if.if.endif, !prof !0
#
# entry.if.if.else:                                 ; preds = %entry.if.if
#   %.67 = extractvalue { i8*, i32, i8*, i8*, i32 } %.38, 2
#   %.68 = call i8* @numba_unpickle(i8* %.43, i32 %.45, i8* %.67)
#   br label %entry.if.if.endif
#
# entry.if.if.endif:                                ; preds = %entry.if.if.if.endif, %entry.if.if.else
#   %.70 = phi i8* [ %.58, %entry.if.if.if.endif ], [ %.68, %entry.if.if.else ]
#   %.71.not = icmp eq i8* %.70, null
#   br i1 %.71.not, label %.35, label %entry.if.if.endif.if, !prof !0
#
# entry.if.if.if.if:                                ; preds = %entry.if.if.if
#   call void @PyErr_SetString(i8* nonnull @PyExc_RuntimeError, i8* getelementptr inbounds ([61 x i8], [61 x i8]* @".const.Error creating Python tuple from runtime exception arguments", i64 0, i64 0))
#   br label %common.ret
#
# entry.if.if.if.endif:                             ; preds = %entry.if.if.if
#   %.58 = call i8* @numba_runtime_build_excinfo_struct(i8* %.47, i8* nonnull %.53)
#   %.59 = bitcast { i8*, i32, i8*, i8*, i32 }* %.18 to i8*
#   call void @NRT_Free(i8* nonnull %.59)
#   br label %entry.if.if.endif
#
# entry.if.if.endif.if:                             ; preds = %entry.if.if.endif
#   call void @numba_do_raise(i8* nonnull %.70)
#   br label %.35
#
# entry.if.endif.endif.endif:                       ; preds = %entry.if
#   call void @PyErr_SetString(i8* nonnull @PyExc_SystemError, i8* getelementptr inbounds ([43 x i8], [43 x i8]* @".const.unknown error when calling native function", i64 0, i64 0))
#   br label %.35
# }
#
# declare void @numba_gil_ensure(i32*) local_unnamed_addr
#
# declare i8* @PyUnicode_FromString(i8*) local_unnamed_addr
#
# declare void @PyErr_WriteUnraisable(i8*) local_unnamed_addr
#
# declare void @Py_DecRef(i8*) local_unnamed_addr
#
# declare void @numba_gil_release(i32*) local_unnamed_addr
#
# declare void @PyErr_Clear() local_unnamed_addr
#
# declare i8* @PyBytes_FromStringAndSize(i8*, i64) local_unnamed_addr
#
# declare i8* @numba_unpickle(i8*, i32, i8*) local_unnamed_addr
#
# declare void @PyErr_SetString(i8*, i8*) local_unnamed_addr
#
# declare i8* @numba_runtime_build_excinfo_struct(i8*, i8*) local_unnamed_addr
#
# declare void @NRT_Free(i8*) local_unnamed_addr
#
# declare void @numba_do_raise(i8*) local_unnamed_addr
#
# declare noalias i8* @NRT_MemInfo_alloc_aligned(i64, i32) local_unnamed_addr
#
# ; Function Attrs: argmemonly nofree nounwind willreturn writeonly
# declare void @llvm.memset.p0i8.i64(i8* nocapture writeonly, i8, i64, i1 immarg) #1
#
# attributes #0 = { mustprogress nofree nosync nounwind readnone speculatable willreturn }
# attributes #1 = { argmemonly nofree nounwind willreturn writeonly }
# attributes #2 = { noinline }
#
# !0 = !{!"branch_weights", i32 1, i32 99}
# !1 = !{i1 true}
# !2 = !{!3, !5, !6, !8}
# !3 = distinct !{!3, !4, !"_ZN5numba2np8arrayobj18_ol_array_allocate12_3clocals_3e4implB2v4B42c8tJTIcFKzyF2ILShI4CrgQElcaMVJhEEUSJJgA_3dEN29typeref_5b_3cclass_20_27numba4core5types8npytypes14Array_27_3e_5dExj: %retptr"}
# !4 = distinct !{!4, !"_ZN5numba2np8arrayobj18_ol_array_allocate12_3clocals_3e4implB2v4B42c8tJTIcFKzyF2ILShI4CrgQElcaMVJhEEUSJJgA_3dEN29typeref_5b_3cclass_20_27numba4core5types8npytypes14Array_27_3e_5dExj"}
# !5 = distinct !{!5, !4, !"_ZN5numba2np8arrayobj18_ol_array_allocate12_3clocals_3e4implB2v4B42c8tJTIcFKzyF2ILShI4CrgQElcaMVJhEEUSJJgA_3dEN29typeref_5b_3cclass_20_27numba4core5types8npytypes14Array_27_3e_5dExj: %excinfo"}
# !6 = distinct !{!6, !7, !"_ZN5numba2np8arrayobj15_call_allocatorB2v3B42c8tJTC_2fWQI8IW1CiAAYKPM6RBFDjESZRVAJmaQIAEN29typeref_5b_3cclass_20_27numba4core5types8npytypes14Array_27_3e_5dExj: %retptr"}
# !7 = distinct !{!7, !"_ZN5numba2np8arrayobj15_call_allocatorB2v3B42c8tJTC_2fWQI8IW1CiAAYKPM6RBFDjESZRVAJmaQIAEN29typeref_5b_3cclass_20_27numba4core5types8npytypes14Array_27_3e_5dExj"}
# !8 = distinct !{!8, !7, !"_ZN5numba2np8arrayobj15_call_allocatorB2v3B42c8tJTC_2fWQI8IW1CiAAYKPM6RBFDjESZRVAJmaQIAEN29typeref_5b_3cclass_20_27numba4core5types8npytypes14Array_27_3e_5dExj: %excinfo"}
# !9 = !{!"branch_weights", i32 99, i32 1}
#
# ================================================================================
# ================================================================================
# --------------------OPTIMIZED DUMP generate_random_numbers_2--------------------
# ; ModuleID = 'generate_random_numbers_2'
# source_filename = "<string>"
# target datalayout = "e-m:e-p270:32:32-p271:32:32-p272:64:64-i64:64-f80:128-n8:16:32:64-S128"
# target triple = "x86_64-unknown-linux-gnu"
#
# @.const.generate_random_numbers_2 = internal constant [26 x i8] c"generate_random_numbers_2\00"
# @_ZN08NumbaEnv8__main__25generate_random_numbers_2B2v1B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dEx = common local_unnamed_addr global i8* null
# @".const.missing Environment: _ZN08NumbaEnv8__main__25generate_random_numbers_2B2v1B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dEx" = internal constant [118 x i8] c"missing Environment: _ZN08NumbaEnv8__main__25generate_random_numbers_2B2v1B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dEx\00"
# @".const.`env.consts` is NULL in `read_const`" = internal constant [37 x i8] c"`env.consts` is NULL in `read_const`\00"
# @.const.pickledata.140636142957920 = internal constant [32 x i8] c"\80\04\95\15\00\00\00\00\00\00\00\8C\05numpy\94\8C\07ndarray\94\93\94."
# @.const.pickledata.140636142957920.sha1 = internal constant [20 x i8] c"\DF\BC\FD\D3\9F\CB&\F4\D0\C6\80\95D\87\B8\C0\B5;\B8\A3"
# @".const.Error creating Python tuple from runtime exception arguments" = internal constant [61 x i8] c"Error creating Python tuple from runtime exception arguments\00"
# @".const.unknown error when calling native function" = internal constant [43 x i8] c"unknown error when calling native function\00"
# @".const.Error creating Python tuple from runtime exception arguments.1" = internal constant [61 x i8] c"Error creating Python tuple from runtime exception arguments\00"
# @".const.unknown error when calling native function.2" = internal constant [43 x i8] c"unknown error when calling native function\00"
# @".const.<numba.core.cpu.CPUContext object at 0x7fe83c426e00>" = internal constant [53 x i8] c"<numba.core.cpu.CPUContext object at 0x7fe83c426e00>\00"
# @_ZN08NumbaEnv5numba2np8arrayobj11ol_np_empty12_3clocals_3e4implB2v2B42c8tJTIcFKzyF2ILShI4CrgQElcaMVJhEEUSJJgA_3dE8UniTupleIxLi1EE17class_28uint64_29 = common local_unnamed_addr global i8* null
# @.const.pickledata.140635422855360 = internal constant [77 x i8] c"\80\04\95B\00\00\00\00\00\00\00\8C\08builtins\94\8C\0AValueError\94\93\94\8C\1Fnegative dimensions not allowed\94\85\94N\87\94."
# @.const.pickledata.140635422855360.sha1 = internal constant [20 x i8] c"3\1B\85c\BD\B9\DA\C8\1B8B\22s\05,Ho\C1pk"
# @.const.picklebuf.140635422855360 = internal constant { i8*, i32, i8*, i8*, i32 } { i8* getelementptr inbounds ([77 x i8], [77 x i8]* @.const.pickledata.140635422855360, i32 0, i32 0), i32 77, i8* getelementptr inbounds ([20 x i8], [20 x i8]* @.const.pickledata.140635422855360.sha1, i32 0, i32 0), i8* null, i32 0 }
# @.const.pickledata.140635420988416 = internal constant [137 x i8] c"\80\04\95~\00\00\00\00\00\00\00\8C\08builtins\94\8C\0AValueError\94\93\94\8C[array is too big; `arr.size * arr.dtype.itemsize` is larger than the maximum possible size.\94\85\94N\87\94."
# @.const.pickledata.140635420988416.sha1 = internal constant [20 x i8] c"X\E1N\CC\B5\07\B1\E0 i\81t\02#\E6\85\CB\8C<W"
# @.const.picklebuf.140635420988416 = internal constant { i8*, i32, i8*, i8*, i32 } { i8* getelementptr inbounds ([137 x i8], [137 x i8]* @.const.pickledata.140635420988416, i32 0, i32 0), i32 137, i8* getelementptr inbounds ([20 x i8], [20 x i8]* @.const.pickledata.140635420988416.sha1, i32 0, i32 0), i8* null, i32 0 }
# @PyExc_RuntimeError = external global i8
# @PyExc_SystemError = external global i8
# @_ZN08NumbaEnv5numba2np8arrayobj15_call_allocatorB2v3B42c8tJTC_2fWQI8IW1CiAAYKPM6RBFDjESZRVAJmaQIAEN29typeref_5b_3cclass_20_27numba4core5types8npytypes14Array_27_3e_5dExj = common local_unnamed_addr global i8* null
# @_ZN08NumbaEnv5numba2np8arrayobj18_ol_array_allocate12_3clocals_3e4implB2v4B42c8tJTIcFKzyF2ILShI4CrgQElcaMVJhEEUSJJgA_3dEN29typeref_5b_3cclass_20_27numba4core5types8npytypes14Array_27_3e_5dExj = common local_unnamed_addr global i8* null
# @.const.pickledata.140635421704384 = internal constant [86 x i8] c"\80\04\95K\00\00\00\00\00\00\00\8C\08builtins\94\8C\0BMemoryError\94\93\94\8C'Allocation failed (probably too large).\94\85\94N\87\94."
# @.const.pickledata.140635421704384.sha1 = internal constant [20 x i8] c"\BA(\9D\81\F0\\p \F3G|\15sH\04\DFe\AB\E2\09"
# @.const.picklebuf.140635421704384 = internal constant { i8*, i32, i8*, i8*, i32 } { i8* getelementptr inbounds ([86 x i8], [86 x i8]* @.const.pickledata.140635421704384, i32 0, i32 0), i32 86, i8* getelementptr inbounds ([20 x i8], [20 x i8]* @.const.pickledata.140635421704384.sha1, i32 0, i32 0), i8* null, i32 0 }
#
# define i32 @_ZN8__main__25generate_random_numbers_2B2v1B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dEx({ i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }* noalias nocapture writeonly %retptr, { i8*, i32, i8*, i8*, i32 }** noalias nocapture writeonly %excinfo, i64 %arg.n) local_unnamed_addr {
# entry:
#   %.18.i = icmp slt i64 %arg.n, 0
#   br i1 %.18.i, label %B0.if, label %B0.endif.endif.i, !prof !0
#
# B0.endif.endif.i:                                 ; preds = %entry
#   %.32.i = tail call { i64, i1 } @llvm.smul.with.overflow.i64(i64 %arg.n, i64 8)
#   %.34.i = extractvalue { i64, i1 } %.32.i, 1
#   br i1 %.34.i, label %B0.if, label %B0.endif.endif.endif.i, !prof !0
#
# B0.endif.endif.endif.i:                           ; preds = %B0.endif.endif.i
#   %.33.i = extractvalue { i64, i1 } %.32.i, 0
#   %.7.i.i.i = tail call i8* @NRT_MemInfo_alloc_aligned(i64 %.33.i, i32 32), !noalias !1
#   %.8.i.i.i = icmp eq i8* %.7.i.i.i, null
#   br i1 %.8.i.i.i, label %B0.if, label %B0.endif.endif, !prof !0
#
# common.ret:                                       ; preds = %B0.if, %B54
#   %common.ret.op = phi i32 [ 0, %B54 ], [ 1, %B0.if ]
#   ret i32 %common.ret.op
#
# B54.loopexit.unr-lcssa:                           ; preds = %B30.else.if, %B30.else.if.preheader
#   %.75.028.unr = phi i64 [ 0, %B30.else.if.preheader ], [ %.144.3, %B30.else.if ]
#   %lcmp.mod.not = icmp eq i64 %xtraiter, 0
#   br i1 %lcmp.mod.not, label %B54, label %B30.else.if.epil.preheader
#
# B30.else.if.epil.preheader:                       ; preds = %B54.loopexit.unr-lcssa
#   %scevgep = getelementptr i64, i64* %.6.i1.i, i64 %.75.028.unr
#   %0 = mul i64 %.75.028.unr, %const
#   br label %B30.else.if.epil
#
# B30.else.if.epil:                                 ; preds = %B30.else.if.epil.preheader, %B30.else.if.epil
#   %lsr.iv = phi i64 [ %0, %B30.else.if.epil.preheader ], [ %lsr.iv.next, %B30.else.if.epil ]
#   %epil.iter = phi i64 [ %epil.iter.next, %B30.else.if.epil ], [ 0, %B30.else.if.epil.preheader ]
#   %1 = udiv i64 %lsr.iv, 2305843009213693951
#   %2 = mul nuw i64 %1, %const48
#   %3 = sub i64 %lsr.iv, %2
#   %scevgep30 = getelementptr i64, i64* %scevgep, i64 %epil.iter
#   store i64 %3, i64* %scevgep30, align 8
#   %epil.iter.next = add i64 %epil.iter, 1
#   %lsr.iv.next = add i64 %lsr.iv, %const
#   %epil.iter.cmp.not = icmp eq i64 %xtraiter, %epil.iter.next
#   br i1 %epil.iter.cmp.not, label %B54, label %B30.else.if.epil, !llvm.loop !11
#
# B54:                                              ; preds = %B30.else.if.epil, %B54.loopexit.unr-lcssa, %B0.endif.endif
#   %retptr.repack49 = bitcast { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }* %retptr to i8**
#   store i8* %.7.i.i.i, i8** %retptr.repack49, align 8
#   %retptr.repack1 = getelementptr inbounds { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }, { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }* %retptr, i64 0, i32 1
#   store i8* null, i8** %retptr.repack1, align 8
#   %retptr.repack3 = getelementptr inbounds { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }, { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }* %retptr, i64 0, i32 2
#   store i64 %arg.n, i64* %retptr.repack3, align 8
#   %retptr.repack5 = getelementptr inbounds { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }, { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }* %retptr, i64 0, i32 3
#   store i64 8, i64* %retptr.repack5, align 8
#   %retptr.repack7 = getelementptr inbounds { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }, { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }* %retptr, i64 0, i32 4
#   store i64* %.6.i1.i, i64** %retptr.repack7, align 8
#   %4 = getelementptr inbounds { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }, { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }* %retptr, i64 0, i32 5, i64 0
#   store i64 %arg.n, i64* %4, align 8
#   %5 = getelementptr inbounds { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }, { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }* %retptr, i64 0, i32 6, i64 0
#   store i64 8, i64* %5, align 8
#   br label %common.ret
#
# B0.if:                                            ; preds = %entry, %B0.endif.endif.i, %B0.endif.endif.endif.i
#   %excinfo.1.0.ph = phi { i8*, i32, i8*, i8*, i32 }* [ @.const.picklebuf.140635421704384, %B0.endif.endif.endif.i ], [ @.const.picklebuf.140635420988416, %B0.endif.endif.i ], [ @.const.picklebuf.140635422855360, %entry ]
#   store { i8*, i32, i8*, i8*, i32 }* %excinfo.1.0.ph, { i8*, i32, i8*, i8*, i32 }** %excinfo, align 8
#   br label %common.ret
#
# B0.endif.endif:                                   ; preds = %B0.endif.endif.endif.i
#   %.5.i.i = getelementptr i8, i8* %.7.i.i.i, i64 24
#   %6 = bitcast i8* %.5.i.i to i64**
#   %.6.i1.i = load i64*, i64** %6, align 8, !noalias !13
#   %.13127.not = icmp eq i64 %arg.n, 0
#   br i1 %.13127.not, label %B54, label %B30.else.if.preheader
#
# B30.else.if.preheader:                            ; preds = %B0.endif.endif
#   %const48 = bitcast i64 2305843009213693951 to i64
#   %const = bitcast i64 437799614237992725 to i64
#   %7 = add i64 %arg.n, -1
#   %xtraiter = and i64 %arg.n, 3
#   %8 = icmp ult i64 %7, 3
#   br i1 %8, label %B54.loopexit.unr-lcssa, label %B30.else.if.preheader.new
#
# B30.else.if.preheader.new:                        ; preds = %B30.else.if.preheader
#   %const47 = bitcast i64 1751198456951970900 to i64
#   %unroll_iter = and i64 %arg.n, -4
#   br label %B30.else.if
#
# B30.else.if:                                      ; preds = %B30.else.if, %B30.else.if.preheader.new
#   %lsr.iv45 = phi i64 [ %lsr.iv.next46, %B30.else.if ], [ 0, %B30.else.if.preheader.new ]
#   %lsr.iv43 = phi i64 [ %lsr.iv.next44, %B30.else.if ], [ 1313398842713978175, %B30.else.if.preheader.new ]
#   %lsr.iv41 = phi i64 [ %lsr.iv.next42, %B30.else.if ], [ %const, %B30.else.if.preheader.new ]
#   %lsr.iv31 = phi i64 [ %lsr.iv.next32, %B30.else.if ], [ 875599228475985450, %B30.else.if.preheader.new ]
#   %.75.028 = phi i64 [ 0, %B30.else.if.preheader.new ], [ %.144.3, %B30.else.if ]
#   %9 = udiv i64 %lsr.iv31, 2305843009213693951
#   %10 = mul nuw i64 %9, %const48
#   %11 = sub i64 %lsr.iv31, %10
#   %12 = udiv i64 %lsr.iv41, 2305843009213693951
#   %13 = mul nuw i64 %12, %const48
#   %14 = sub i64 %lsr.iv41, %13
#   %15 = udiv i64 %lsr.iv43, 2305843009213693951
#   %16 = mul nuw i64 %15, %const48
#   %17 = sub i64 %lsr.iv43, %16
#   %18 = udiv i64 %lsr.iv45, 2305843009213693951
#   %19 = mul nuw i64 %18, %const48
#   %20 = sub i64 %lsr.iv45, %19
#   %sunkaddr = mul i64 %.75.028, 8
#   %21 = bitcast i64* %.6.i1.i to i8*
#   %sunkaddr50 = getelementptr i8, i8* %21, i64 %sunkaddr
#   %22 = bitcast i8* %sunkaddr50 to i64*
#   store i64 %20, i64* %22, align 8
#   %sunkaddr51 = mul i64 %.75.028, 8
#   %23 = bitcast i64* %.6.i1.i to i8*
#   %sunkaddr52 = getelementptr i8, i8* %23, i64 %sunkaddr51
#   %sunkaddr53 = getelementptr i8, i8* %sunkaddr52, i64 8
#   %24 = bitcast i8* %sunkaddr53 to i64*
#   store i64 %14, i64* %24, align 8
#   %sunkaddr54 = mul i64 %.75.028, 8
#   %25 = bitcast i64* %.6.i1.i to i8*
#   %sunkaddr55 = getelementptr i8, i8* %25, i64 %sunkaddr54
#   %sunkaddr56 = getelementptr i8, i8* %sunkaddr55, i64 16
#   %26 = bitcast i8* %sunkaddr56 to i64*
#   store i64 %11, i64* %26, align 8
#   %.144.3 = add nuw i64 %.75.028, 4
#   %sunkaddr57 = mul i64 %.75.028, 8
#   %27 = bitcast i64* %.6.i1.i to i8*
#   %sunkaddr58 = getelementptr i8, i8* %27, i64 %sunkaddr57
#   %sunkaddr59 = getelementptr i8, i8* %sunkaddr58, i64 24
#   %28 = bitcast i8* %sunkaddr59 to i64*
#   store i64 %17, i64* %28, align 8
#   %lsr.iv.next32 = add i64 %lsr.iv31, %const47
#   %lsr.iv.next42 = add i64 %lsr.iv41, %const47
#   %lsr.iv.next44 = add i64 %lsr.iv43, %const47
#   %lsr.iv.next46 = add i64 %lsr.iv45, %const47
#   %niter.ncmp.3 = icmp eq i64 %unroll_iter, %.144.3
#   br i1 %niter.ncmp.3, label %B54.loopexit.unr-lcssa, label %B30.else.if
# }
#
# define i8* @_ZN7cpython8__main__25generate_random_numbers_2B2v1B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dEx(i8* nocapture readnone %py_closure, i8* %py_args, i8* nocapture readnone %py_kws) local_unnamed_addr {
# entry:
#   %.5 = alloca i8*, align 8
#   %.6 = call i32 (i8*, i8*, i64, i64, ...) @PyArg_UnpackTuple(i8* %py_args, i8* getelementptr inbounds ([26 x i8], [26 x i8]* @.const.generate_random_numbers_2, i64 0, i64 0), i64 1, i64 1, i8** nonnull %.5)
#   %.7 = icmp eq i32 %.6, 0
#   %.36 = alloca { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }, align 8
#   %excinfo = alloca { i8*, i32, i8*, i8*, i32 }*, align 8
#   store { i8*, i32, i8*, i8*, i32 }* null, { i8*, i32, i8*, i8*, i32 }** %excinfo, align 8
#   %.90 = alloca { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }, align 8
#   br i1 %.7, label %common.ret, label %entry.endif, !prof !0
#
# common.ret:                                       ; preds = %entry.endif.endif.endif.endif.endif.if.endif, %entry.endif.endif.endif.endif.endif.if.endif.if, %entry.endif.endif.endif.endif.endif.endif.endif.endif, %entry.endif.endif.endif, %entry, %entry.endif.endif.endif.endif.endif.if.if.if, %entry.endif.endif.endif.endif.if.endif.endif, %entry.endif.if
#   %common.ret.op = phi i8* [ null, %entry.endif.if ], [ %.94, %entry.endif.endif.endif.endif.if.endif.endif ], [ null, %entry.endif.endif.endif.endif.endif.if.if.if ], [ null, %entry ], [ null, %entry.endif.endif.endif ], [ null, %entry.endif.endif.endif.endif.endif.endif.endif.endif ], [ null, %entry.endif.endif.endif.endif.endif.if.endif.if ], [ null, %entry.endif.endif.endif.endif.endif.if.endif ]
#   ret i8* %common.ret.op
#
# entry.endif:                                      ; preds = %entry
#   %.11 = load i8*, i8** @_ZN08NumbaEnv8__main__25generate_random_numbers_2B2v1B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dEx, align 8
#   %.16 = icmp eq i8* %.11, null
#   br i1 %.16, label %entry.endif.if, label %entry.endif.endif, !prof !0
#
# entry.endif.if:                                   ; preds = %entry.endif
# ...
#   store i64 %.50.fca.6.0.load, i64* %28, align 8
#   %.93 = bitcast { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }* %.90 to i8*
#   %.94 = call i8* @NRT_adapt_ndarray_to_python_acqref(i8* nonnull %.93, i8* %.89, i32 1, i32 1, i8* %.72.0)
#   call void @NRT_decref(i8* %.50.fca.0.load)
#   br label %common.ret
#
# entry.endif.endif.endif.endif.endif.if:           ; preds = %entry.endif.endif.endif.endif.endif
#   call void @PyErr_Clear()
#   %.102 = load { i8*, i32, i8*, i8*, i32 }, { i8*, i32, i8*, i8*, i32 }* %.49, align 8
#   %.103 = extractvalue { i8*, i32, i8*, i8*, i32 } %.102, 4
#   %.104 = icmp sgt i32 %.103, 0
#   %.107 = extractvalue { i8*, i32, i8*, i8*, i32 } %.102, 0
#   %.109 = extractvalue { i8*, i32, i8*, i8*, i32 } %.102, 1
#   br i1 %.104, label %entry.endif.endif.endif.endif.endif.if.if, label %entry.endif.endif.endif.endif.endif.if.else
#
# entry.endif.endif.endif.endif.endif.if.if:        ; preds = %entry.endif.endif.endif.endif.endif.if
#   %.110 = sext i32 %.109 to i64
#   %.111 = call i8* @PyBytes_FromStringAndSize(i8* %.107, i64 %.110)
#   %.112 = load { i8*, i32, i8*, i8*, i32 }, { i8*, i32, i8*, i8*, i32 }* %.49, align 8
#   %.113 = extractvalue { i8*, i32, i8*, i8*, i32 } %.112, 2
#   %.115 = extractvalue { i8*, i32, i8*, i8*, i32 } %.112, 3
#   %.116 = bitcast i8* %.115 to i8* (i8*)*
#   %.117 = call i8* %.116(i8* %.113)
#   %.118 = icmp eq i8* %.117, null
#   br i1 %.118, label %entry.endif.endif.endif.endif.endif.if.if.if, label %entry.endif.endif.endif.endif.endif.if.if.endif, !prof !0
#
# entry.endif.endif.endif.endif.endif.if.else:      ; preds = %entry.endif.endif.endif.endif.endif.if
#   %.131 = extractvalue { i8*, i32, i8*, i8*, i32 } %.102, 2
#   %.132 = call i8* @numba_unpickle(i8* %.107, i32 %.109, i8* %.131)
#   br label %entry.endif.endif.endif.endif.endif.if.endif
#
# entry.endif.endif.endif.endif.endif.if.endif:     ; preds = %entry.endif.endif.endif.endif.endif.if.if.endif, %entry.endif.endif.endif.endif.endif.if.else
#   %.134 = phi i8* [ %.122, %entry.endif.endif.endif.endif.endif.if.if.endif ], [ %.132, %entry.endif.endif.endif.endif.endif.if.else ]
#   %.135.not = icmp eq i8* %.134, null
#   br i1 %.135.not, label %common.ret, label %entry.endif.endif.endif.endif.endif.if.endif.if, !prof !0
#
# entry.endif.endif.endif.endif.endif.if.if.if:     ; preds = %entry.endif.endif.endif.endif.endif.if.if
#   call void @PyErr_SetString(i8* nonnull @PyExc_RuntimeError, i8* getelementptr inbounds ([61 x i8], [61 x i8]* @".const.Error creating Python tuple from runtime exception arguments", i64 0, i64 0))
#   br label %common.ret
#
# entry.endif.endif.endif.endif.endif.if.if.endif:  ; preds = %entry.endif.endif.endif.endif.endif.if.if
#   %.122 = call i8* @numba_runtime_build_excinfo_struct(i8* %.111, i8* nonnull %.117)
#   %.123 = bitcast { i8*, i32, i8*, i8*, i32 }* %.49 to i8*
#   call void @NRT_Free(i8* nonnull %.123)
#   br label %entry.endif.endif.endif.endif.endif.if.endif
#
# entry.endif.endif.endif.endif.endif.if.endif.if:  ; preds = %entry.endif.endif.endif.endif.endif.if.endif
#   call void @numba_do_raise(i8* nonnull %.134)
#   br label %common.ret
#
# entry.endif.endif.endif.endif.endif.endif.endif.endif: ; preds = %entry.endif.endif.endif.endif.endif
#   call void @PyErr_SetString(i8* nonnull @PyExc_SystemError, i8* getelementptr inbounds ([43 x i8], [43 x i8]* @".const.unknown error when calling native function", i64 0, i64 0))
#   br label %common.ret
# }
#
# declare i32 @PyArg_UnpackTuple(i8*, i8*, i64, i64, ...) local_unnamed_addr
#
# declare void @PyErr_SetString(i8*, i8*) local_unnamed_addr
#
# declare i8* @PyNumber_Long(i8*) local_unnamed_addr
#
# declare i64 @PyLong_AsLongLong(i8*) local_unnamed_addr
#
# declare void @Py_DecRef(i8*) local_unnamed_addr
#
# declare i8* @PyErr_Occurred() local_unnamed_addr
#
# declare i8* @PyList_GetItem(i8*, i64) local_unnamed_addr
#
# declare i8* @numba_unpickle(i8*, i32, i8*) local_unnamed_addr
#
# declare i8* @NRT_adapt_ndarray_to_python_acqref(i8* nocapture, i8*, i32, i32, i8*) local_unnamed_addr
#
# declare void @PyErr_Clear() local_unnamed_addr
#
# declare i8* @PyBytes_FromStringAndSize(i8*, i64) local_unnamed_addr
#
# declare i8* @numba_runtime_build_excinfo_struct(i8*, i8*) local_unnamed_addr
#
# declare void @NRT_Free(i8*) local_unnamed_addr
#
# declare void @numba_do_raise(i8*) local_unnamed_addr
#
# define { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] } @cfunc._ZN8__main__25generate_random_numbers_2B2v1B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dEx(i64 %.1) local_unnamed_addr {
# entry:
#   %.3 = alloca { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }, align 8
#   %.fca.0.gep1 = bitcast { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }* %.3 to i8**
#   %.fca.1.gep = getelementptr inbounds { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }, { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }* %.3, i64 0, i32 1
#   %.fca.2.gep = getelementptr inbounds { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }, { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }* %.3, i64 0, i32 2
#   %.fca.3.gep = getelementptr inbounds { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }, { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }* %.3, i64 0, i32 3
#   %.fca.4.gep = getelementptr inbounds { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }, { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }* %.3, i64 0, i32 4
#   %.fca.5.0.gep = getelementptr inbounds { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }, { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }* %.3, i64 0, i32 5, i64 0
#   %.fca.6.0.gep = getelementptr inbounds { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }, { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }* %.3, i64 0, i32 6, i64 0
#   %excinfo = alloca { i8*, i32, i8*, i8*, i32 }*, align 8
#   %0 = bitcast { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }* %.3 to i8*
#   call void @llvm.memset.p0i8.i64(i8* noundef nonnull align 8 dereferenceable(56) %0, i8 0, i64 56, i1 false)
#   store { i8*, i32, i8*, i8*, i32 }* null, { i8*, i32, i8*, i8*, i32 }** %excinfo, align 8
#   %.7 = call i32 @_ZN8__main__25generate_random_numbers_2B2v1B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dEx({ i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] }* nonnull %.3, { i8*, i32, i8*, i8*, i32 }** nonnull %excinfo, i64 %.1) #1
#   %.8 = load { i8*, i32, i8*, i8*, i32 }*, { i8*, i32, i8*, i8*, i32 }** %excinfo, align 8
#   %.9.not = icmp eq i32 %.7, 0
#   %.15 = icmp sgt i32 %.7, 0
#   %.16 = select i1 %.15, { i8*, i32, i8*, i8*, i32 }* %.8, { i8*, i32, i8*, i8*, i32 }* undef
#   %.17.fca.0.load = load i8*, i8** %.fca.0.gep1, align 8
#   %.17.fca.1.load = load i8*, i8** %.fca.1.gep, align 8
#   %.17.fca.2.load = load i64, i64* %.fca.2.gep, align 8
#   %.17.fca.3.load = load i64, i64* %.fca.3.gep, align 8
#   %.17.fca.4.load = load i64*, i64** %.fca.4.gep, align 8
#   %.17.fca.5.0.load = load i64, i64* %.fca.5.0.gep, align 8
#   %.17.fca.6.0.load = load i64, i64* %.fca.6.0.gep, align 8
#   %.23 = insertvalue [1 x i64] poison, i64 %.17.fca.5.0.load, 0
#   %.24 = insertvalue [1 x i64] poison, i64 %.17.fca.6.0.load, 0
#   %inserted.meminfo = insertvalue { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] } undef, i8* %.17.fca.0.load, 0
#   %inserted.parent = insertvalue { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] } %inserted.meminfo, i8* %.17.fca.1.load, 1
#   %inserted.nitems = insertvalue { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] } %inserted.parent, i64 %.17.fca.2.load, 2
#   %inserted.itemsize = insertvalue { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] } %inserted.nitems, i64 %.17.fca.3.load, 3
#   %inserted.data = insertvalue { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] } %inserted.itemsize, i64* %.17.fca.4.load, 4
#   %inserted.shape = insertvalue { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] } %inserted.data, [1 x i64] %.23, 5
#   %inserted.strides = insertvalue { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] } %inserted.shape, [1 x i64] %.24, 6
#   %.30 = alloca i32, align 4
#   store i32 0, i32* %.30, align 4
#   br i1 %.9.not, label %common.ret, label %entry.if, !prof !14
#
# entry.if:                                         ; preds = %entry
#   %1 = icmp sgt i32 %.7, 0
#   call void @numba_gil_ensure(i32* nonnull %.30)
#   br i1 %1, label %entry.if.if, label %entry.if.endif.endif.endif
#
# common.ret:                                       ; preds = %entry, %.33, %entry.if.if.if.if
#   %common.ret.op = phi { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] } [ zeroinitializer, %entry.if.if.if.if ], [ %inserted.strides, %.33 ], [ %inserted.strides, %entry ]
#   ret { i8*, i8*, i64, i64, i64*, [1 x i64], [1 x i64] } %common.ret.op
#
# .33:                                              ; preds = %entry.if.if.endif, %entry.if.if.endif.if, %entry.if.endif.endif.endif
#   %.81 = call i8* @PyUnicode_FromString(i8* getelementptr inbounds ([53 x i8], [53 x i8]* @".const.<numba.core.cpu.CPUContext object at 0x7fe83c426e00>", i64 0, i64 0))
#   call void @PyErr_WriteUnraisable(i8* %.81)
#   call void @Py_DecRef(i8* %.81)
#   call void @numba_gil_release(i32* nonnull %.30)
#   br label %common.ret
#
# entry.if.if:                                      ; preds = %entry.if
#   call void @PyErr_Clear()
#   %.36 = load { i8*, i32, i8*, i8*, i32 }, { i8*, i32, i8*, i8*, i32 }* %.16, align 8
#   %.37 = extractvalue { i8*, i32, i8*, i8*, i32 } %.36, 4
#   %.38 = icmp sgt i32 %.37, 0
#   %.41 = extractvalue { i8*, i32, i8*, i8*, i32 } %.36, 0
#   %.43 = extractvalue { i8*, i32, i8*, i8*, i32 } %.36, 1
#   br i1 %.38, label %entry.if.if.if, label %entry.if.if.else
#
# entry.if.if.if:                                   ; preds = %entry.if.if
#   %.44 = sext i32 %.43 to i64
#   %.45 = call i8* @PyBytes_FromStringAndSize(i8* %.41, i64 %.44)
#   %.46 = load { i8*, i32, i8*, i8*, i32 }, { i8*, i32, i8*, i8*, i32 }* %.16, align 8
#   %.47 = extractvalue { i8*, i32, i8*, i8*, i32 } %.46, 2
#   %.49 = extractvalue { i8*, i32, i8*, i8*, i32 } %.46, 3
#   %.50 = bitcast i8* %.49 to i8* (i8*)*
#   %.51 = call i8* %.50(i8* %.47)
#   %.52 = icmp eq i8* %.51, null
#   br i1 %.52, label %entry.if.if.if.if, label %entry.if.if.if.endif, !prof !0
#
# entry.if.if.else:                                 ; preds = %entry.if.if
#   %.65 = extractvalue { i8*, i32, i8*, i8*, i32 } %.36, 2
#   %.66 = call i8* @numba_unpickle(i8* %.41, i32 %.43, i8* %.65)
#   br label %entry.if.if.endif
#
# entry.if.if.endif:                                ; preds = %entry.if.if.if.endif, %entry.if.if.else
#   %.68 = phi i8* [ %.56, %entry.if.if.if.endif ], [ %.66, %entry.if.if.else ]
#   %.69.not = icmp eq i8* %.68, null
#   br i1 %.69.not, label %.33, label %entry.if.if.endif.if, !prof !0
#
# entry.if.if.if.if:                                ; preds = %entry.if.if.if
#   call void @PyErr_SetString(i8* nonnull @PyExc_RuntimeError, i8* getelementptr inbounds ([61 x i8], [61 x i8]* @".const.Error creating Python tuple from runtime exception arguments.1", i64 0, i64 0))
#   br label %common.ret
#
# entry.if.if.if.endif:                             ; preds = %entry.if.if.if
#   %.56 = call i8* @numba_runtime_build_excinfo_struct(i8* %.45, i8* nonnull %.51)
#   %.57 = bitcast { i8*, i32, i8*, i8*, i32 }* %.16 to i8*
#   call void @NRT_Free(i8* nonnull %.57)
#   br label %entry.if.if.endif
#
# entry.if.if.endif.if:                             ; preds = %entry.if.if.endif
#   call void @numba_do_raise(i8* nonnull %.68)
#   br label %.33
#
# entry.if.endif.endif.endif:                       ; preds = %entry.if
#   call void @PyErr_SetString(i8* nonnull @PyExc_SystemError, i8* getelementptr inbounds ([43 x i8], [43 x i8]* @".const.unknown error when calling native function.2", i64 0, i64 0))
#   br label %.33
# }
#
# declare void @numba_gil_ensure(i32*) local_unnamed_addr
#
# declare i8* @PyUnicode_FromString(i8*) local_unnamed_addr
#
# declare void @PyErr_WriteUnraisable(i8*) local_unnamed_addr
#
# declare void @numba_gil_release(i32*) local_unnamed_addr
#
# ; Function Attrs: mustprogress nofree nosync nounwind readnone speculatable willreturn
# declare { i64, i1 } @llvm.smul.with.overflow.i64(i64, i64) #0
#
# declare noalias i8* @NRT_MemInfo_alloc_aligned(i64, i32) local_unnamed_addr
#
# ; Function Attrs: noinline
# define linkonce_odr void @NRT_decref(i8* %.1) local_unnamed_addr #1 {
# .3:
#   %.4 = icmp eq i8* %.1, null
#   br i1 %.4, label %common.ret1, label %.3.endif, !prof !0
#
# common.ret1:                                      ; preds = %.3, %.3.endif
#   ret void
#
# .3.endif:                                         ; preds = %.3
#   fence release
#   %.8 = bitcast i8* %.1 to i64*
#   %.4.i = atomicrmw sub i64* %.8, i64 1 monotonic, align 8
#   %.10 = icmp eq i64 %.4.i, 1
#   br i1 %.10, label %.3.endif.if, label %common.ret1, !prof !0
#
# .3.endif.if:                                      ; preds = %.3.endif
#   fence acquire
#   tail call void @NRT_MemInfo_call_dtor(i8* nonnull %.1)
#   ret void
# }
#
# declare void @NRT_MemInfo_call_dtor(i8*) local_unnamed_addr
#
# ; Function Attrs: argmemonly nofree nounwind willreturn writeonly
# declare void @llvm.memset.p0i8.i64(i8* nocapture writeonly, i8, i64, i1 immarg) #2
#
# attributes #0 = { mustprogress nofree nosync nounwind readnone speculatable willreturn }
# attributes #1 = { noinline }
# attributes #2 = { argmemonly nofree nounwind willreturn writeonly }
#
# !0 = !{!"branch_weights", i32 1, i32 99}
# !1 = !{!2, !4, !5, !7, !8, !10}
# !2 = distinct !{!2, !3, !"_ZN5numba2np8arrayobj18_ol_array_allocate12_3clocals_3e4implB2v4B42c8tJTIcFKzyF2ILShI4CrgQElcaMVJhEEUSJJgA_3dEN29typeref_5b_3cclass_20_27numba4core5types8npytypes14Array_27_3e_5dExj: %retptr"}
# !3 = distinct !{!3, !"_ZN5numba2np8arrayobj18_ol_array_allocate12_3clocals_3e4implB2v4B42c8tJTIcFKzyF2ILShI4CrgQElcaMVJhEEUSJJgA_3dEN29typeref_5b_3cclass_20_27numba4core5types8npytypes14Array_27_3e_5dExj"}
# !4 = distinct !{!4, !3, !"_ZN5numba2np8arrayobj18_ol_array_allocate12_3clocals_3e4implB2v4B42c8tJTIcFKzyF2ILShI4CrgQElcaMVJhEEUSJJgA_3dEN29typeref_5b_3cclass_20_27numba4core5types8npytypes14Array_27_3e_5dExj: %excinfo"}
# !5 = distinct !{!5, !6, !"_ZN5numba2np8arrayobj15_call_allocatorB2v3B42c8tJTC_2fWQI8IW1CiAAYKPM6RBFDjESZRVAJmaQIAEN29typeref_5b_3cclass_20_27numba4core5types8npytypes14Array_27_3e_5dExj: %retptr"}
# !6 = distinct !{!6, !"_ZN5numba2np8arrayobj15_call_allocatorB2v3B42c8tJTC_2fWQI8IW1CiAAYKPM6RBFDjESZRVAJmaQIAEN29typeref_5b_3cclass_20_27numba4core5types8npytypes14Array_27_3e_5dExj"}
# !7 = distinct !{!7, !6, !"_ZN5numba2np8arrayobj15_call_allocatorB2v3B42c8tJTC_2fWQI8IW1CiAAYKPM6RBFDjESZRVAJmaQIAEN29typeref_5b_3cclass_20_27numba4core5types8npytypes14Array_27_3e_5dExj: %excinfo"}
# !8 = distinct !{!8, !9, !"_ZN5numba2np8arrayobj11ol_np_empty12_3clocals_3e4implB2v2B42c8tJTIcFKzyF2ILShI4CrgQElcaMVJhEEUSJJgA_3dE8UniTupleIxLi1EE17class_28uint64_29: %retptr"}
# !9 = distinct !{!9, !"_ZN5numba2np8arrayobj11ol_np_empty12_3clocals_3e4implB2v2B42c8tJTIcFKzyF2ILShI4CrgQElcaMVJhEEUSJJgA_3dE8UniTupleIxLi1EE17class_28uint64_29"}
# !10 = distinct !{!10, !9, !"_ZN5numba2np8arrayobj11ol_np_empty12_3clocals_3e4implB2v2B42c8tJTIcFKzyF2ILShI4CrgQElcaMVJhEEUSJJgA_3dE8UniTupleIxLi1EE17class_28uint64_29: %excinfo"}
# !11 = distinct !{!11, !12}
# !12 = !{!"llvm.loop.unroll.disable"}
# !13 = !{!8, !10}
# !14 = !{!"branch_weights", i32 99, i32 1}
#
# ================================================================================
# LV: Checking a loop in "_ZN8__main__25generate_random_numbers_2B2v1B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dEx" from generate_random_numbers_2
# LV: Loop hints: force=? width=0 interleave=0
# LV: Not vectorizing: No #pragma vectorize enable.
# LV: Loop hints prevent vectorization.
# array([                  0,  437799614237992725,  875599228475985450,
#        1313398842713978175, 1751198456951970900, 2188998071189963625,
#         320954676214262399,  758754290452255124, 1196553904690247849,
#        1634353518928240574, 2072153133166233299,  204109738190532073,
#         641909352428524798, 1079708966666517523, 1517508580904510248,
#        1955308195142502973,   87264800166801747,  525064414404794472,
#         962864028642787197, 1400663642880779922, 1838463257118772647,
#        2276262871356765372,  408219476381064146,  846019090619056871,
#        1283818704857049596, 1721618319095042321, 2159417933333035046,
#         291374538357333820,  729174152595326545, 1166973766833319270],
#       dtype=uint64)

# %%
# %timeit generate_random_numbers_2(1_000_000)
# Out:
# 6.99 ms ± 35.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
@njit
def generate_random_numbers_3(n):
    result = np.empty((n,), dtype=np.uint64)
    for i in range(n // 2):
        random_number1 = ((i * 2) * 437799614237992725) % (2 ** 61 - 1)
        result[i * 2] = random_number1
        random_number2 = ((i * 2 + 1) * 437799614237992725) % (2 ** 61 - 1)
        result[i * 2 + 1] = random_number2
    result[-1] = ((n - 1) * 437799614237992725) % (2 ** 61 - 1)
    return result

generate_random_numbers_3(30)
# Out:
# array([                  0,  437799614237992725,  875599228475985450,
#        1313398842713978175, 1751198456951970900, 2188998071189963625,
#         320954676214262399,  758754290452255124, 1196553904690247849,
#        1634353518928240574, 2072153133166233299,  204109738190532073,
#         641909352428524798, 1079708966666517523, 1517508580904510248,
#        1955308195142502973,   87264800166801747,  525064414404794472,
#         962864028642787197, 1400663642880779922, 1838463257118772647,
#        2276262871356765372,  408219476381064138,  846019090619056863,
#        1283818704857049588, 1721618319095042313, 2159417933333035038,
#         291374538357333812,  729174152595326537, 1166973766833319262],
#       dtype=uint64)

# %%
# %timeit generate_random_numbers_3(1_000_000)
# Out:
# 5.16 ms ± 34.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
from importlib import reload
import sys
os.environ["NUMBA_OPT"] = "3"
to_remove = [m for m in sys.modules if m.startswith("numba")]
for m in to_remove:
    sys.modules.pop(m)
import numba
reload(numba)
from numba import njit

# %%
@njit
def generate_random_numbers_2b(n):
    result = np.empty((n,), dtype=np.uint64)
    for i in range(n):
        random_number = (i * 437799614237992725) % (2 ** 61 - 1)
        result[i] = random_number
    return result

generate_random_numbers_2b(30)
# Out:
# LV: Checking a loop in "_ZN8__main__26generate_random_numbers_2bB2v1B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dEx" from generate_random_numbers_2b
# LV: Loop hints: force=? width=0 interleave=0
# LV: Not vectorizing: No #pragma vectorize enable.
# LV: Loop hints prevent vectorization.
# array([                  0,  437799614237992725,  875599228475985450,
#        1313398842713978175, 1751198456951970900, 2188998071189963625,
#         320954676214262399,  758754290452255124, 1196553904690247849,
#        1634353518928240574, 2072153133166233299,  204109738190532073,
#         641909352428524798, 1079708966666517523, 1517508580904510248,
#        1955308195142502973,   87264800166801747,  525064414404794472,
#         962864028642787197, 1400663642880779922, 1838463257118772647,
#        2276262871356765372,  408219476381064146,  846019090619056871,
#        1283818704857049596, 1721618319095042321, 2159417933333035046,
#         291374538357333820,  729174152595326545, 1166973766833319270],
#       dtype=uint64)

# %%
# %timeit generate_random_numbers_2b(1_000_000)
# Out:
# 497 µs ± 4.7 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
# Increases linearly from 1 to 1,000,000:
PREDICTABLE_DATA = np.linspace(1, 1_000_000, 1_000_000, dtype=np.uint64)
# Shuffled randomly:
RANDOM_DATA = PREDICTABLE_DATA.copy()
np.random.shuffle(RANDOM_DATA)

# %%
from numba import float64

@njit 
def count_increasing_decreasing(arr):
    previous = 0
    increasing = 0
    unchanged = 0
    for value in arr:
        if value == previous:
            unchanged += 1
        elif value > previous:
            increasing += 1
        previous = value
    decreasing = len(arr) - increasing - unchanged
    return increasing, unchanged, decreasing

count_increasing_decreasing([1, 2, 3, 2, 2, 4])
# Out:
# /home/itamarst/devel/business/performance/low-level-performance/venv/lib/python3.10/site-packages/numba/core/ir_utils.py:2149: NumbaPendingDeprecationWarning:
# Encountered the use of a type that is scheduled for deprecation: type 'reflected list' found for argument 'arr' of function 'count_increasing_decreasing'.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-reflection-for-list-and-set-types
#
# File "../../../../../../../tmp/ipykernel_3649244/89310949.py", line 3:
# <source missing, REPL/exec in use?>
#
#   warnings.warn(NumbaPendingDeprecationWarning(msg, loc=loc))
#
# LV: Checking a loop in "_ZN8__main__27count_increasing_decreasingB3v15B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dE42reflected_20list_28int64_29_3civ_3dNone_3e" from count_increasing_decreasing
# LV: Loop hints: force=? width=0 interleave=0
# LV: Not vectorizing: No #pragma vectorize enable.
# LV: Loop hints prevent vectorization.
#
# LV: Checking a loop in "_ZN7cpython8__main__27count_increasing_decreasingB3v15B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dE42reflected_20list_28int64_29_3civ_3dNone_3e" from count_increasing_decreasing
# LV: Loop hints: force=? width=0 interleave=0
# LV: Not vectorizing: No #pragma vectorize enable.
# LV: Loop hints prevent vectorization.
#
# LV: Checking a loop in "_ZN7cpython8__main__27count_increasing_decreasingB3v15B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dE42reflected_20list_28int64_29_3civ_3dNone_3e" from count_increasing_decreasing
# LV: Loop hints: force=? width=0 interleave=0
# LV: Not vectorizing: No #pragma vectorize enable.
# LV: Loop hints prevent vectorization.
#
# LV: Checking a loop in "_ZN7cpython8__main__27count_increasing_decreasingB3v15B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dE42reflected_20list_28int64_29_3civ_3dNone_3e" from count_increasing_decreasing
# LV: Loop hints: force=? width=0 interleave=0
# LV: Not vectorizing: No #pragma vectorize enable.
# LV: Loop hints prevent vectorization.
#
# LV: Checking a loop in "_ZN7cpython8__main__27count_increasing_decreasingB3v15B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dE42reflected_20list_28int64_29_3civ_3dNone_3e" from count_increasing_decreasing
# LV: Loop hints: force=? width=0 interleave=0
# LV: Not vectorizing: No #pragma vectorize enable.
# LV: Loop hints prevent vectorization.
# (4, 1, 1)

# %%
# %timeit count_increasing_decreasing(PREDICTABLE_DATA)
# %timeit count_increasing_decreasing(RANDOM_DATA)
# Out:
# LV: Checking a loop in "_ZN8__main__27count_increasing_decreasingB3v16B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dE5ArrayIyLi1E1C7mutable7alignedE" from count_increasing_decreasing
# LV: Loop hints: force=? width=0 interleave=0
# LV: Not vectorizing: No #pragma vectorize enable.
# LV: Loop hints prevent vectorization.
# 498 µs ± 3.39 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 3.25 ms ± 14.9 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
from numba import float64

@njit 
def count_increasing_decreasing_avoid_conditionals(arr):
    previous = 0
    increasing = 0
    unchanged = 0
    for value in arr:
        unchanged += 1 if value == previous else 0
        increasing += 1 if value > previous else 0
        previous = value
    decreasing = len(arr) - increasing - unchanged
    return increasing, unchanged, decreasing

count_increasing_decreasing_avoid_conditionals([1, 2, 3, 2, 2, 4])
# Out:
# ================================================================================
# ----------------------------------ASSEMBLY nrt----------------------------------
# 	.text
# 	.file	"<string>"
# 	.globl	nrt_atomic_add
# 	.p2align	4, 0x90
# 	.type	nrt_atomic_add,@function
# nrt_atomic_add:
# 	movl	$1, %eax
# 	lock		xaddq	%rax, (%rdi)
# 	incq	%rax
# 	retq
# .Lfunc_end0:
# 	.size	nrt_atomic_add, .Lfunc_end0-nrt_atomic_add
#
# 	.globl	nrt_atomic_sub
# 	.p2align	4, 0x90
# 	.type	nrt_atomic_sub,@function
# nrt_atomic_sub:
# 	movq	$-1, %rax
# 	lock		xaddq	%rax, (%rdi)
# 	decq	%rax
# 	retq
# .Lfunc_end1:
# 	.size	nrt_atomic_sub, .Lfunc_end1-nrt_atomic_sub
#
# 	.globl	nrt_atomic_cas
# 	.p2align	4, 0x90
# 	.type	nrt_atomic_cas,@function
# nrt_atomic_cas:
# 	movq	%rsi, %rax
# 	xorl	%esi, %esi
# 	lock		cmpxchgq	%rdx, (%rdi)
# 	sete	%sil
# 	movq	%rax, (%rcx)
# 	movl	%esi, %eax
# 	retq
# .Lfunc_end2:
# 	.size	nrt_atomic_cas, .Lfunc_end2-nrt_atomic_cas
#
# 	.globl	NRT_MemInfo_data_fast
# 	.p2align	4, 0x90
# 	.type	NRT_MemInfo_data_fast,@function
# NRT_MemInfo_data_fast:
# 	movq	24(%rdi), %rax
# 	retq
# .Lfunc_end3:
# 	.size	NRT_MemInfo_data_fast, .Lfunc_end3-NRT_MemInfo_data_fast
#
# 	.globl	NRT_incref
# 	.p2align	4, 0x90
# 	.type	NRT_incref,@function
# NRT_incref:
# 	testq	%rdi, %rdi
# 	je	.LBB4_2
# 	lock		incq	(%rdi)
# .LBB4_2:
# 	retq
# .Lfunc_end4:
# 	.size	NRT_incref, .Lfunc_end4-NRT_incref
#
# 	.globl	NRT_decref
# 	.p2align	4, 0x90
# 	.type	NRT_decref,@function
# NRT_decref:
# 	.cfi_startproc
# 	testq	%rdi, %rdi
# 	je	.LBB5_2
# 	#MEMBARRIER
# 	lock		decq	(%rdi)
# 	je	.LBB5_3
# .LBB5_2:
# 	retq
# .LBB5_3:
# 	#MEMBARRIER
# 	movabsq	$NRT_MemInfo_call_dtor, %rax
# 	jmpq	*%rax
# .Lfunc_end5:
# 	.size	NRT_decref, .Lfunc_end5-NRT_decref
# 	.cfi_endproc
#
# 	.globl	nrt_unresolved_abort
# 	.p2align	4, 0x90
# 	.type	nrt_unresolved_abort,@function
# nrt_unresolved_abort:
# 	movabsq	$.const.picklebuf.140502055809472, %rax
# 	movq	%rax, (%rsi)
# 	movl	$1, %eax
# 	retq
# .Lfunc_end6:
# 	.size	nrt_unresolved_abort, .Lfunc_end6-nrt_unresolved_abort
#
# 	.type	.const.pickledata.140502055809472,@object
# 	.section	.rodata,"a",@progbits
# 	.p2align	4
# .const.pickledata.140502055809472:
# 	.ascii	"\200\004\225[\000\000\000\000\000\000\000\214\bbuiltins\224\214\fRuntimeError\224\223\224\2146numba jitted function aborted due to unresolved symbol\224\205\224N\207\224."
# 	.size	.const.pickledata.140502055809472, 102
#
# 	.type	.const.pickledata.140502055809472.sha1,@object
# 	.p2align	4
# .const.pickledata.140502055809472.sha1:
# 	.ascii	"\227\276\334\337\354\216\200\267\t>P\316%\355V\367r\016\f\234"
# 	.size	.const.pickledata.140502055809472.sha1, 20
#
# 	.type	.const.picklebuf.140502055809472,@object
# 	.p2align	4
# .const.picklebuf.140502055809472:
# 	.quad	.const.pickledata.140502055809472
# 	.long	102
# 	.zero	4
# 	.quad	.const.pickledata.140502055809472.sha1
# 	.quad	0
# 	.long	0
# 	.zero	4
# 	.size	.const.picklebuf.140502055809472, 40
#
# 	.section	".note.GNU-stack","",@progbits
#
# ================================================================================
# ================================================================================
# ------------ASSEMBLY count_increasing_decreasing_avoid_conditionals-------------
# 	.text
# 	.file	"<string>"
# 	.globl	_ZN8__main__46count_increasing_decreasing_avoid_conditionalsB2v1B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dE42reflected_20list_28int64_29_3civ_3dNone_3e
# 	.p2align	4, 0x90
# 	.type	_ZN8__main__46count_increasing_decreasing_avoid_conditionalsB2v1B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dE42reflected_20list_28int64_29_3civ_3dNone_3e,@function
# _ZN8__main__46count_increasing_decreasing_avoid_conditionalsB2v1B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dE42reflected_20list_28int64_29_3civ_3dNone_3e:
# 	pushq	%r15
# 	pushq	%r14
# 	pushq	%r12
# 	pushq	%rbx
# 	movq	24(%rdx), %r11
# 	movq	(%r11), %r8
# 	testq	%r8, %r8
# 	jle	.LBB0_1
# 	leaq	-1(%r8), %rax
# 	movl	%r8d, %r9d
# 	andl	$3, %r9d
# 	cmpq	$3, %rax
# 	jae	.LBB0_4
# 	xorl	%r12d, %r12d
# 	xorl	%esi, %esi
# 	xorl	%eax, %eax
# 	xorl	%ecx, %ecx
# 	jmp	.LBB0_6
# .LBB0_1:
# 	xorl	%eax, %eax
# 	xorl	%esi, %esi
# 	jmp	.LBB0_9
# .LBB0_4:
# 	movq	%r8, %r10
# 	andq	$-4, %r10
# 	xorl	%r12d, %r12d
# 	xorl	%esi, %esi
# 	xorl	%eax, %eax
# 	xorl	%ecx, %ecx
# 	.p2align	4, 0x90
# .LBB0_5:
# 	movq	24(%r11,%rcx,8), %r15
# 	movq	32(%r11,%rcx,8), %r14
# 	xorl	%ebx, %ebx
# 	xorl	%edx, %edx
# 	cmpq	%r12, %r15
# 	sete	%bl
# 	setg	%dl
# 	addq	%rax, %rbx
# 	addq	%rsi, %rdx
# 	xorl	%eax, %eax
# 	xorl	%esi, %esi
# 	cmpq	%r15, %r14
# 	sete	%al
# 	setg	%sil
# 	addq	%rbx, %rax
# 	addq	%rdx, %rsi
# 	movq	40(%r11,%rcx,8), %r15
# 	xorl	%edx, %edx
# 	xorl	%ebx, %ebx
# 	cmpq	%r14, %r15
# 	sete	%dl
# 	setg	%bl
# 	addq	%rax, %rdx
# 	addq	%rsi, %rbx
# 	movq	48(%r11,%rcx,8), %r12
# 	addq	$4, %rcx
# 	xorl	%eax, %eax
# 	xorl	%esi, %esi
# 	cmpq	%r15, %r12
# 	sete	%al
# 	setg	%sil
# 	addq	%rdx, %rax
# 	addq	%rbx, %rsi
# 	cmpq	%rcx, %r10
# 	jne	.LBB0_5
# .LBB0_6:
# 	testq	%r9, %r9
# 	je	.LBB0_9
# 	leaq	(%r11,%rcx,8), %r10
# 	addq	$24, %r10
# 	xorl	%ecx, %ecx
# 	.p2align	4, 0x90
# .LBB0_8:
# 	movq	(%r10,%rcx,8), %r11
# 	xorl	%ebx, %ebx
# 	xorl	%edx, %edx
# 	cmpq	%r12, %r11
# 	sete	%bl
# 	setg	%dl
# 	addq	%rbx, %rax
# 	addq	%rdx, %rsi
# 	incq	%rcx
# 	movq	%r11, %r12
# 	cmpq	%rcx, %r9
# 	jne	.LBB0_8
# .LBB0_9:
# 	subq	%rsi, %r8
# 	subq	%rax, %r8
# 	movq	%rsi, (%rdi)
# 	movq	%rax, 8(%rdi)
# 	movq	%r8, 16(%rdi)
# 	xorl	%eax, %eax
# 	popq	%rbx
# 	popq	%r12
# 	popq	%r14
# 	popq	%r15
# 	retq
# .Lfunc_end0:
# 	.size	_ZN8__main__46count_increasing_decreasing_avoid_conditionalsB2v1B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dE42reflected_20list_28int64_29_3civ_3dNone_3e, .Lfunc_end0-_ZN8__main__46count_increasing_decreasing_avoid_conditionalsB2v1B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dE42reflected_20list_28int64_29_3civ_3dNone_3e
#
# 	.globl	_ZN7cpython8__main__46count_increasing_decreasing_avoid_conditionalsB2v1B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dE42reflected_20list_28int64_29_3civ_3dNone_3e
# 	.p2align	4, 0x90
# 	.type	_ZN7cpython8__main__46count_increasing_decreasing_avoid_conditionalsB2v1B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dE42reflected_20list_28int64_29_3civ_3dNone_3e,@function
# _ZN7cpython8__main__46count_increasing_decreasing_avoid_conditionalsB2v1B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dE42reflected_20list_28int64_29_3civ_3dNone_3e:
# 	.cfi_startproc
# 	pushq	%rbp
# 	.cfi_def_cfa_offset 16
# 	pushq	%r15
# 	.cfi_def_cfa_offset 24
# 	pushq	%r14
# 	.cfi_def_cfa_offset 32
# 	pushq	%r13
# 	.cfi_def_cfa_offset 40
# 	pushq	%r12
# 	.cfi_def_cfa_offset 48
# 	pushq	%rbx
# 	.cfi_def_cfa_offset 56
# 	subq	$88, %rsp
# 	.cfi_def_cfa_offset 144
# 	.cfi_offset %rbx, -56
# 	.cfi_offset %r12, -48
# 	.cfi_offset %r13, -40
# 	.cfi_offset %r14, -32
# 	.cfi_offset %r15, -24
# 	.cfi_offset %rbp, -16
# 	movq	%rsi, %rdi
# 	movabsq	$.const.count_increasing_decreasing_avoid_conditionals, %rsi
# 	movabsq	$PyArg_UnpackTuple, %rbx
# 	xorl	%ebp, %ebp
# 	leaq	80(%rsp), %r8
# 	movl	$1, %edx
# 	movl	$1, %ecx
# 	xorl	%eax, %eax
# 	callq	*%rbx
# 	testl	%eax, %eax
# 	je	.LBB1_23
# 	movabsq	$_ZN08NumbaEnv8__main__46count_increasing_decreasing_avoid_conditionalsB2v1B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dE42reflected_20list_28int64_29_3civ_3dNone_3e, %rax
# 	cmpq	$0, (%rax)
# 	je	.LBB1_24
# 	movq	80(%rsp), %r13
# 	movabsq	$PyList_Size, %rax
# 	movq	%r13, %rdi
# 	callq	*%rax
# 	movq	%rax, %rbp
# 	movabsq	$numba_get_pyobject_private_data, %rax
# 	movq	%r13, %rdi
# 	callq	*%rax
# 	testq	%rax, %rax
# 	je	.LBB1_6
# 	movq	%rax, %r12
# 	movabsq	$NRT_incref, %rax
# 	movq	%r12, %rdi
# 	callq	*%rax
# 	movq	%r12, %rax
# 	addq	$24, %rax
# 	movq	%rax, 8(%rsp)
# 	movq	24(%r12), %rax
# 	movq	%rbp, (%rax)
# .LBB1_4:
# 	vxorps	%xmm0, %xmm0, %xmm0
# 	vmovaps	%xmm0, 48(%rsp)
# 	movq	$0, 64(%rsp)
# 	movabsq	$_ZN8__main__46count_increasing_decreasing_avoid_conditionalsB2v1B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dE42reflected_20list_28int64_29_3civ_3dNone_3e, %rax
# 	leaq	48(%rsp), %rdi
# 	movq	%r12, %rdx
# 	callq	*%rax
# 	movq	48(%rsp), %r14
# 	movq	56(%rsp), %r15
# 	movq	64(%rsp), %rcx
# 	movq	24(%r12), %rax
# 	cmpb	$0, 16(%rax)
# 	movabsq	$PyLong_FromLongLong, %rbx
# 	movq	%rcx, 24(%rsp)
# 	jne	.LBB1_25
# .LBB1_5:
# 	movabsq	$numba_reset_pyobject_private_data, %rax
# 	movq	%r13, %rdi
# 	callq	*%rax
# 	movabsq	$NRT_decref, %rax
# 	movq	%r12, %rdi
# 	callq	*%rax
# 	movabsq	$PyTuple_New, %rax
# 	movl	$3, %edi
# 	callq	*%rax
# 	movq	%rax, %rbp
# 	movq	%r14, %rdi
# 	callq	*%rbx
# 	movabsq	$PyTuple_SetItem, %r14
# 	movq	%rbp, %rdi
# 	xorl	%esi, %esi
# 	movq	%rax, %rdx
# 	callq	*%r14
# 	movq	%r15, %rdi
# 	callq	*%rbx
# 	movq	%rbp, %rdi
# 	movl	$1, %esi
# 	movq	%rax, %rdx
# 	callq	*%r14
# 	movq	24(%rsp), %rdi
# 	callq	*%rbx
# 	movq	%rbp, %rdi
# 	movl	$2, %esi
# 	movq	%rax, %rdx
# 	callq	*%r14
# 	jmp	.LBB1_23
# .LBB1_6:
# 	imulq	$8, %rbp, %rdi
# 	addq	$24, %rdi
# 	seto	%al
# 	xorl	%edx, %edx
# 	imulq	$8, %rbp, %rcx
# 	jo	.LBB1_21
# 	testb	%al, %al
# 	jne	.LBB1_21
# 	movabsq	$.dtor.list.int64, %rsi
# 	movabsq	$NRT_MemInfo_new_varsize_dtor, %rax
# 	callq	*%rax
# 	testq	%rax, %rax
# 	je	.LBB1_32
# 	movq	%rax, %r12
# 	addq	$24, %rax
# 	movq	%rax, 8(%rsp)
# 	movq	24(%r12), %rax
# 	movq	%rbp, 8(%rax)
# 	movq	24(%r12), %rax
# 	movq	$0, (%rax)
# 	movq	24(%r12), %rax
# 	movb	$0, 16(%rax)
# 	movq	24(%r12), %rdi
# 	addq	$24, %rdi
# 	leaq	(,%rbp,8), %rdx
# 	movabsq	$memset, %rax
# 	xorl	%esi, %esi
# 	callq	*%rax
# 	movq	24(%r12), %rax
# 	movq	%rbp, (%rax)
# 	testq	%rbp, %rbp
# 	jle	.LBB1_18
# 	movq	%r12, 32(%rsp)
# 	movabsq	$.const.numba, %rdi
# 	movabsq	$PyImport_ImportModuleNoBlock, %rax
# 	callq	*%rax
# 	movq	%rax, %rbx
# 	movabsq	$.const.typeof, %rsi
# 	movabsq	$PyObject_GetAttrString, %rax
# 	movq	%rbx, %rdi
# 	callq	*%rax
# 	movq	%rax, %r14
# 	movabsq	$Py_DecRef, %rax
# 	movq	%rbx, %rdi
# 	callq	*%rax
# 	movabsq	$PyList_GetItem, %rax
# 	movq	%r13, 40(%rsp)
# 	movq	%r13, %rdi
# 	xorl	%esi, %esi
# 	callq	*%rax
# 	movabsq	$PyObject_CallFunctionObjArgs, %rcx
# 	movq	%r14, 24(%rsp)
# 	movq	%r14, %rdi
# 	movq	%rax, %rsi
# 	xorl	%edx, %edx
# 	xorl	%eax, %eax
# 	callq	*%rcx
# 	movq	%rax, 16(%rsp)
# 	xorl	%ebx, %ebx
# 	xorl	%r14d, %r14d
# 	.p2align	4, 0x90
# .LBB1_11:
# 	movq	%rbp, %r13
# 	movq	40(%rsp), %rdi
# 	movq	%rbx, %rsi
# 	movabsq	$PyList_GetItem, %rax
# 	callq	*%rax
# 	movq	%rax, %r15
# 	movq	24(%rsp), %rdi
# 	movq	%rax, %rsi
# 	xorl	%edx, %edx
# 	xorl	%eax, %eax
# 	movabsq	$PyObject_CallFunctionObjArgs, %rcx
# 	callq	*%rcx
# 	testq	%rax, %rax
# 	je	.LBB1_20
# 	movq	%rax, %r12
# 	movq	16(%rsp), %rdx
# 	cmpq	%rdx, %rax
# 	jne	.LBB1_19
# 	movq	%rdx, %rdi
# 	movabsq	$Py_DecRef, %r12
# 	callq	*%r12
# 	movq	%r15, %rdi
# 	movabsq	$PyNumber_Long, %rax
# 	callq	*%rax
# 	testq	%rax, %rax
# 	je	.LBB1_15
# 	movq	%rax, %rbp
# 	movq	%rax, %rdi
# 	movabsq	$PyLong_AsLongLong, %rax
# 	callq	*%rax
# 	movq	%rax, %r14
# 	movq	%rbp, %rdi
# 	callq	*%r12
# .LBB1_15:
# 	movabsq	$PyErr_Occurred, %rax
# 	callq	*%rax
# 	testq	%rax, %rax
# 	jne	.LBB1_20
# 	movq	8(%rsp), %rcx
# 	movq	(%rcx), %rax
# 	movq	%r14, 24(%rax,%rbx,8)
# 	movq	(%rcx), %rax
# 	movb	$1, 16(%rax)
# 	incq	%rbx
# 	movq	%r13, %rbp
# 	cmpq	%rbx, %r13
# 	jne	.LBB1_11
# 	movq	16(%rsp), %rdi
# 	movabsq	$Py_DecRef, %rbx
# 	callq	*%rbx
# 	movq	24(%rsp), %rdi
# 	callq	*%rbx
# 	movq	32(%rsp), %r12
# 	movq	40(%rsp), %r13
# .LBB1_18:
# 	movabsq	$numba_set_pyobject_private_data, %rax
# 	movq	%r13, %rdi
# 	movq	%r12, %rsi
# 	callq	*%rax
# 	movq	24(%r12), %rax
# 	movb	$0, 16(%rax)
# 	jmp	.LBB1_4
# .LBB1_19:
# 	movabsq	$PyExc_TypeError, %rdi
# 	movabsq	$".const.can't unbox heterogeneous list: %S != %S", %rsi
# 	movabsq	$PyErr_Format, %rbp
# 	movq	%r12, %rcx
# 	xorl	%eax, %eax
# 	callq	*%rbp
# 	movq	%r12, %rdi
# 	movabsq	$Py_DecRef, %rax
# 	callq	*%rax
# .LBB1_20:
# 	movq	16(%rsp), %rdi
# 	movabsq	$Py_DecRef, %rbx
# 	callq	*%rbx
# 	movq	24(%rsp), %rdi
# 	callq	*%rbx
# 	movq	8(%rsp), %rax
# 	movq	(%rax), %rax
# 	movb	$0, 16(%rax)
# 	movq	32(%rsp), %rdx
# .LBB1_21:
# 	movabsq	$NRT_decref, %rax
# 	movq	%rdx, %rdi
# 	callq	*%rax
# .LBB1_22:
# 	xorl	%ebp, %ebp
# .LBB1_23:
# 	movq	%rbp, %rax
# 	addq	$88, %rsp
# 	.cfi_def_cfa_offset 56
# 	popq	%rbx
# 	.cfi_def_cfa_offset 48
# 	popq	%r12
# 	.cfi_def_cfa_offset 40
# 	popq	%r13
# 	.cfi_def_cfa_offset 32
# 	popq	%r14
# 	.cfi_def_cfa_offset 24
# 	popq	%r15
# 	.cfi_def_cfa_offset 16
# 	popq	%rbp
# 	.cfi_def_cfa_offset 8
# 	retq
# .LBB1_24:
# 	.cfi_def_cfa_offset 144
# 	movabsq	$PyExc_RuntimeError, %rdi
# 	movabsq	$".const.missing Environment: _ZN08NumbaEnv8__main__46count_increasing_decreasing_avoid_conditionalsB2v1B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dE42reflected_20list_28int64_29_3civ_3dNone_3e", %rsi
# 	movabsq	$PyErr_SetString, %rax
# 	callq	*%rax
# 	jmp	.LBB1_22
# .LBB1_25:
# 	movq	%r15, 16(%rsp)
# 	movq	%r12, 32(%rsp)
# 	movq	%r13, %rdi
# 	movabsq	$PyList_Size, %rax
# 	callq	*%rax
# 	movq	%rax, %rbx
# 	movq	8(%rsp), %rcx
# 	movq	(%rcx), %rax
# 	movq	(%rax), %rbp
# 	movq	%rbp, %rdx
# 	subq	%rbx, %rdx
# 	js	.LBB1_33
# 	movq	%rdx, 72(%rsp)
# 	movq	%rbp, 40(%rsp)
# 	testq	%rbx, %rbx
# 	movabsq	$PyLong_FromLongLong, %r12
# 	jle	.LBB1_30
# 	movq	24(%rax), %rdi
# 	callq	*%r12
# 	movabsq	$PyList_SetItem, %rcx
# 	movq	%r13, %rdi
# 	xorl	%esi, %esi
# 	movq	%rax, %rdx
# 	callq	*%rcx
# 	movq	8(%rsp), %rcx
# 	cmpq	$1, %rbx
# 	je	.LBB1_30
# 	movq	%rbx, %r15
# 	decq	%r15
# 	xorl	%ebp, %ebp
# .LBB1_29:
# 	movq	(%rcx), %rax
# 	movq	32(%rax,%rbp,8), %rdi
# 	incq	%rbp
# 	callq	*%r12
# 	movq	%r13, %rdi
# 	movq	%rbp, %rsi
# 	movq	%rax, %rdx
# 	movabsq	$PyList_SetItem, %rax
# 	callq	*%rax
# 	movq	8(%rsp), %rcx
# 	cmpq	%rbp, %r15
# 	jne	.LBB1_29
# .LBB1_30:
# 	cmpq	$0, 72(%rsp)
# 	movq	40(%rsp), %r15
# 	jle	.LBB1_36
# .LBB1_31:
# 	movq	(%rcx), %rax
# 	movq	24(%rax,%rbx,8), %rdi
# 	callq	*%r12
# 	movq	%rax, %rbp
# 	movq	%r13, %rdi
# 	movq	%rax, %rsi
# 	movabsq	$PyList_Append, %rax
# 	callq	*%rax
# 	movq	%rbp, %rdi
# 	movabsq	$Py_DecRef, %rax
# 	callq	*%rax
# 	movq	8(%rsp), %rcx
# 	incq	%rbx
# 	cmpq	%rbx, %r15
# 	jne	.LBB1_31
# 	jmp	.LBB1_36
# .LBB1_32:
# 	xorl	%edx, %edx
# 	jmp	.LBB1_21
# .LBB1_33:
# 	movabsq	$PyList_SetSlice, %rax
# 	movq	%r13, %rdi
# 	movq	%rbp, %rsi
# 	movq	%rbx, %rdx
# 	xorl	%ecx, %ecx
# 	callq	*%rax
# 	movq	8(%rsp), %rcx
# 	testq	%rbp, %rbp
# 	movabsq	$PyLong_FromLongLong, %r12
# 	jle	.LBB1_36
# 	movq	%rbp, %rbx
# 	xorl	%ebp, %ebp
# 	movabsq	$PyList_SetItem, %r15
# .LBB1_35:
# 	movq	(%rcx), %rax
# 	movq	24(%rax,%rbp,8), %rdi
# 	callq	*%r12
# 	movq	%r13, %rdi
# 	movq	%rbp, %rsi
# 	movq	%rax, %rdx
# 	callq	*%r15
# 	movq	8(%rsp), %rcx
# 	incq	%rbp
# 	cmpq	%rbp, %rbx
# 	jne	.LBB1_35
# .LBB1_36:
# 	movq	(%rcx), %rax
# 	movb	$0, 16(%rax)
# 	movq	%r12, %rbx
# 	movq	32(%rsp), %r12
# 	movq	16(%rsp), %r15
# 	jmp	.LBB1_5
# .Lfunc_end1:
# 	.size	_ZN7cpython8__main__46count_increasing_decreasing_avoid_conditionalsB2v1B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dE42reflected_20list_28int64_29_3civ_3dNone_3e, .Lfunc_end1-_ZN7cpython8__main__46count_increasing_decreasing_avoid_conditionalsB2v1B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dE42reflected_20list_28int64_29_3civ_3dNone_3e
# 	.cfi_endproc
#
# 	.weak	.dtor.list.int64
# 	.p2align	4, 0x90
# 	.type	.dtor.list.int64,@function
# .dtor.list.int64:
# 	.cfi_startproc
# 	retq
# .Lfunc_end2:
# 	.size	.dtor.list.int64, .Lfunc_end2-.dtor.list.int64
# 	.cfi_endproc
#
# 	.globl	cfunc._ZN8__main__46count_increasing_decreasing_avoid_conditionalsB2v1B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dE42reflected_20list_28int64_29_3civ_3dNone_3e
# 	.p2align	4, 0x90
# 	.type	cfunc._ZN8__main__46count_increasing_decreasing_avoid_conditionalsB2v1B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dE42reflected_20list_28int64_29_3civ_3dNone_3e,@function
# cfunc._ZN8__main__46count_increasing_decreasing_avoid_conditionalsB2v1B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dE42reflected_20list_28int64_29_3civ_3dNone_3e:
# 	subq	$24, %rsp
# 	movq	%rdi, %rdx
# 	vxorps	%xmm0, %xmm0, %xmm0
# 	vmovaps	%xmm0, (%rsp)
# 	movq	$0, 16(%rsp)
# 	movabsq	$_ZN8__main__46count_increasing_decreasing_avoid_conditionalsB2v1B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dE42reflected_20list_28int64_29_3civ_3dNone_3e, %rax
# 	movq	%rsp, %rdi
# 	callq	*%rax
# 	movq	(%rsp), %rax
# 	movq	8(%rsp), %rdx
# 	movq	16(%rsp), %rcx
# 	addq	$24, %rsp
# 	retq
# .Lfunc_end3:
# 	.size	cfunc._ZN8__main__46count_increasing_decreasing_avoid_conditionalsB2v1B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dE42reflected_20list_28int64_29_3civ_3dNone_3e, .Lfunc_end3-cfunc._ZN8__main__46count_increasing_decreasing_avoid_conditionalsB2v1B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dE42reflected_20list_28int64_29_3civ_3dNone_3e
#
# 	.weak	NRT_incref
# 	.p2align	4, 0x90
# 	.type	NRT_incref,@function
# NRT_incref:
# 	testq	%rdi, %rdi
# 	je	.LBB4_2
# 	lock		incq	(%rdi)
# .LBB4_2:
# 	retq
# .Lfunc_end4:
# 	.size	NRT_incref, .Lfunc_end4-NRT_incref
#
# 	.weak	NRT_decref
# 	.p2align	4, 0x90
# 	.type	NRT_decref,@function
# NRT_decref:
# 	.cfi_startproc
# 	testq	%rdi, %rdi
# 	je	.LBB5_2
# 	#MEMBARRIER
# 	lock		decq	(%rdi)
# 	je	.LBB5_3
# .LBB5_2:
# 	retq
# .LBB5_3:
# 	#MEMBARRIER
# 	movabsq	$NRT_MemInfo_call_dtor, %rax
# 	jmpq	*%rax
# .Lfunc_end5:
# 	.size	NRT_decref, .Lfunc_end5-NRT_decref
# 	.cfi_endproc
#
# 	.type	.const.count_increasing_decreasing_avoid_conditionals,@object
# 	.section	.rodata,"a",@progbits
# 	.p2align	4
# .const.count_increasing_decreasing_avoid_conditionals:
# 	.asciz	"count_increasing_decreasing_avoid_conditionals"
# 	.size	.const.count_increasing_decreasing_avoid_conditionals, 47
#
# 	.type	_ZN08NumbaEnv8__main__46count_increasing_decreasing_avoid_conditionalsB2v1B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dE42reflected_20list_28int64_29_3civ_3dNone_3e,@object
# 	.comm	_ZN08NumbaEnv8__main__46count_increasing_decreasing_avoid_conditionalsB2v1B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dE42reflected_20list_28int64_29_3civ_3dNone_3e,8,8
# 	.type	".const.missing Environment: _ZN08NumbaEnv8__main__46count_increasing_decreasing_avoid_conditionalsB2v1B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dE42reflected_20list_28int64_29_3civ_3dNone_3e",@object
# 	.p2align	4
# ".const.missing Environment: _ZN08NumbaEnv8__main__46count_increasing_decreasing_avoid_conditionalsB2v1B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dE42reflected_20list_28int64_29_3civ_3dNone_3e":
# 	.asciz	"missing Environment: _ZN08NumbaEnv8__main__46count_increasing_decreasing_avoid_conditionalsB2v1B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dE42reflected_20list_28int64_29_3civ_3dNone_3e"
# 	.size	".const.missing Environment: _ZN08NumbaEnv8__main__46count_increasing_decreasing_avoid_conditionalsB2v1B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dE42reflected_20list_28int64_29_3civ_3dNone_3e", 182
#
# 	.type	.const.numba,@object
# .const.numba:
# 	.asciz	"numba"
# 	.size	.const.numba, 6
#
# 	.type	.const.typeof,@object
# .const.typeof:
# 	.asciz	"typeof"
# 	.size	.const.typeof, 7
#
# 	.type	".const.can't unbox heterogeneous list: %S != %S",@object
# 	.p2align	4
# ".const.can't unbox heterogeneous list: %S != %S":
# 	.asciz	"can't unbox heterogeneous list: %S != %S"
# 	.size	".const.can't unbox heterogeneous list: %S != %S", 41
#
# 	.section	".note.GNU-stack","",@progbits
#
# ================================================================================
# /home/itamarst/devel/business/performance/low-level-performance/venv/lib/python3.10/site-packages/numba/core/ir_utils.py:2149: NumbaPendingDeprecationWarning:
# Encountered the use of a type that is scheduled for deprecation: type 'reflected list' found for argument 'arr' of function 'count_increasing_decreasing_avoid_conditionals'.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-reflection-for-list-and-set-types
#
# File "../../../../../../../tmp/ipykernel_3673217/2673960763.py", line 3:
# <source missing, REPL/exec in use?>
#
#   warnings.warn(NumbaPendingDeprecationWarning(msg, loc=loc))
#
# LV: Checking a loop in "_ZN8__main__46count_increasing_decreasing_avoid_conditionalsB2v1B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dE42reflected_20list_28int64_29_3civ_3dNone_3e" from count_increasing_decreasing_avoid_conditionals
# LV: Loop hints: force=? width=0 interleave=0
# LV: Not vectorizing: No #pragma vectorize enable.
# LV: Loop hints prevent vectorization.
#
# LV: Checking a loop in "_ZN7cpython8__main__46count_increasing_decreasing_avoid_conditionalsB2v1B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dE42reflected_20list_28int64_29_3civ_3dNone_3e" from count_increasing_decreasing_avoid_conditionals
# LV: Loop hints: force=? width=0 interleave=0
# LV: Not vectorizing: No #pragma vectorize enable.
# LV: Loop hints prevent vectorization.
#
# LV: Checking a loop in "_ZN7cpython8__main__46count_increasing_decreasing_avoid_conditionalsB2v1B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dE42reflected_20list_28int64_29_3civ_3dNone_3e" from count_increasing_decreasing_avoid_conditionals
# LV: Loop hints: force=? width=0 interleave=0
# LV: Not vectorizing: No #pragma vectorize enable.
# LV: Loop hints prevent vectorization.
#
# LV: Checking a loop in "_ZN7cpython8__main__46count_increasing_decreasing_avoid_conditionalsB2v1B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dE42reflected_20list_28int64_29_3civ_3dNone_3e" from count_increasing_decreasing_avoid_conditionals
# LV: Loop hints: force=? width=0 interleave=0
# LV: Not vectorizing: No #pragma vectorize enable.
# LV: Loop hints prevent vectorization.
#
# LV: Checking a loop in "_ZN7cpython8__main__46count_increasing_decreasing_avoid_conditionalsB2v1B38c8tJTIcFKzyF2ILShI4CrgQElQb6HczSBAA_3dE42reflected_20list_28int64_29_3civ_3dNone_3e" from count_increasing_decreasing_avoid_conditionals
# LV: Loop hints: force=? width=0 interleave=0
# LV: Not vectorizing: No #pragma vectorize enable.
# LV: Loop hints prevent vectorization.
# (4, 1, 1)

# %%
# %timeit count_increasing_decreasing_avoid_conditionals(PREDICTABLE_DATA)
# %timeit count_increasing_decreasing_avoid_conditionals(RANDOM_DATA)
# Out:
# 725 µs ± 5.84 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 728 µs ± 10.2 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
